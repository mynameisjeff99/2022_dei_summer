# %% [markdown]
# https://www.thepythoncode.com/article/gender-detection-using-opencv-in-python

# %%
import sys
import json
import cv2
import time
import numpy as np
from urllib.request import Request, urlopen

# %%
# The gender model architecture
# https://drive.google.com/open?id=1W_moLzMlGiELyPxWiYQJ9KFaXroQ_NFQ
GENDER_MODEL = 'weights/deploy_gender.prototxt'
# The gender model pre-trained weights
# https://drive.google.com/open?id=1AW3WduLk1haTVAxHOkVS_BEzel1WXQHP
GENDER_PROTO = 'weights/gender_net.caffemodel'
# Each Caffe Model impose the shape of the input image also image preprocessing is required like mean
# substraction to eliminate the effect of illunination changes
MODEL_MEAN_VALUES = (78.4263377603, 87.7689143744, 114.895847746)
# Represent the gender classes
GENDER_LIST = ['male', 'female']
# https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt
FACE_PROTO = "weights/deploy.prototxt.txt"
# https://raw.githubusercontent.com/opencv/opencv_3rdparty/dnn_samples_face_detector_20180205_fp16/res10_300x300_ssd_iter_140000_fp16.caffemodel
FACE_MODEL = "weights/res10_300x300_ssd_iter_140000_fp16.caffemodel"

# %%
# load face Caffe model
face_net = cv2.dnn.readNetFromCaffe(FACE_PROTO, FACE_MODEL)
# Load gender prediction model
gender_net = cv2.dnn.readNetFromCaffe(GENDER_MODEL, GENDER_PROTO)

# %%
# https://stackoverflow.com/questions/44650888/resize-an-image-without-distortion-opencv
def image_resize(image, width = None, height = None, inter = cv2.INTER_AREA):
    # initialize the dimensions of the image to be resized and
    # grab the image size
    dim = None
    (h, w) = image.shape[:2]
    # if both the width and height are None, then return the
    # original image
    if width is None and height is None:
        return image
    # check to see if the width is None
    if width is None:
        # calculate the ratio of the height and construct the
        # dimensions
        r = height / float(h)
        dim = (int(w * r), height)
    # otherwise, the height is None
    else:
        # calculate the ratio of the width and construct the
        # dimensions
        r = width / float(w)
        dim = (width, int(h * r))
    # resize the image
    return cv2.resize(image, dim, interpolation = inter)

# %%
def get_face(frame, confidence_threshold=0.5):
    # convert the frame into a blob to be ready for NN input
    blob = cv2.dnn.blobFromImage(frame, 1.0, (300, 300), (104, 177.0, 123.0))
    # set the image as input to the NN
    face_net.setInput(blob)
    # perform inference and get predictions
    output = np.squeeze(face_net.forward())
    # initialize the result list
    # Loop over the faces detected
    for i in range(output.shape[0]):
        confidence = output[i, 2]
        if confidence > confidence_threshold:
            box = output[i, 3:7] * \
                np.array([frame.shape[1], frame.shape[0],
                         frame.shape[1], frame.shape[0]])
            # convert to integers
            start_x, start_y, end_x, end_y = box.astype(np.int)
            # widen the box a little
            start_x, start_y, end_x, end_y = start_x - \
                10, start_y - 10, end_x + 10, end_y + 10
            start_x = 0 if start_x < 0 else start_x
            start_y = 0 if start_y < 0 else start_y
            end_x = 0 if end_x < 0 else end_x
            end_y = 0 if end_y < 0 else end_y
            # append to our list
            return start_x, start_y, end_x, end_y
    raise Exception("Face not found")

# %%
def predict_gender(url):
    """Predict the gender of the faces showing in the image"""
    # Read Input Image
    # https://stackoverflow.com/questions/21061814/how-can-i-read-an-image-from-an-internet-url-in-python-cv2-scikit-image-and-mah
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    arr = np.asarray(bytearray(webpage), dtype=np.uint8)
    img = cv2.imdecode(arr, -1)
    # grey scale --> convert to 3 channels
    if len(img.shape) == 2:
        img = cv2.merge((img,img,img))
    
    # Initialize frame size
    frame_width = 640
    frame_height = 360

    # Take a copy of the initial image and resize it
    frame = img.copy()
    #if frame.shape[1] > frame_width:
    frame = image_resize(frame, width=frame_width)
    # predict the faces
    start_x, start_y, end_x, end_y = get_face(frame)
    face_img = frame[start_y: end_y, start_x: end_x]
    
    # image --> Input image to preprocess before passing it through our dnn for classification.
    # scale factor = After performing mean substraction we can optionally scale the image by some factor. (if 1 -> no scaling)
    # size = The spatial size that the CNN expects. Options are = (224*224, 227*227 or 299*299)
    # mean = mean substraction values to be substracted from every channel of the image.
    # swapRB=OpenCV assumes images in BGR whereas the mean is supplied in RGB. To resolve this we set swapRB to True.
    blob = cv2.dnn.blobFromImage(image=face_img, scalefactor=1.0, size=(
            227, 227), mean=MODEL_MEAN_VALUES, swapRB=False, crop=False)

    gender_net.setInput(blob)
    gender_preds = gender_net.forward()
    i = gender_preds[0].argmax()
    gender = GENDER_LIST[i]
    gender_confidence_score = gender_preds[0][i]
    return gender, gender_confidence_score
        
    # Cleanup
    cv2.destroyAllWindows()

# %%
with open(sys.path[0] + '/../data/columbia_test_sans_processing_w_name_gender_race.json') as f:
    columbia = json.load(f)

# %%
for department in columbia:
    print(department.get('department'))
    start = time.time()
    if department.get('profiles') is not None:
        for p in department.get('profiles'):
            gender = None,
            gender_confidence_score = None
            img_url = p.get('img')
            try:
                gender, gender_confidence_score = predict_gender(img_url)
                p.update({'gender_img':gender, 'gender_confidence_score_img':str(gender_confidence_score_img)})
            except:
                p.update({'gender_img':None, 'gender_confidence_score_img':None})
                pass
        end = time.time()
        print(f'Time taken = {end-start:.1f} seconds for {len(department.get("profiles"))} profiles')
    else:
        print("No profiles")
    print("____________________________________")
# Out:
# Accounting Division
# Time taken = 21.8 seconds for 25 profiles
# ____________________________________
# African American and African Diaspora Studies Department
# Time taken = 8.3 seconds for 14 profiles
# ____________________________________
# Africana Studies (Barnard College)
# Time taken = 1.9 seconds for 5 profiles
# ____________________________________
# Anthropology (Barnard College)
# Time taken = 4.4 seconds for 9 profiles
# ____________________________________
# Anthropology Department
# No profiles
# ____________________________________
# Applied Physics and Applied Mathematics Department
# Time taken = 4.0 seconds for 11 profiles
# ____________________________________
# Architecture (Barnard College)
# Time taken = 3.4 seconds for 15 profiles
# ____________________________________
# Art History (Barnard College)
# No profiles
# ____________________________________
# Art History and Archaeology Department
# No profiles
# ____________________________________
# Asian and Middle Eastern Cultures (Barnard College)
# No profiles
# ____________________________________
# Astronomy and Astrophysics Department
# Time taken = 9.8 seconds for 14 profiles
# ____________________________________
# Biological Sciences Department
# Time taken = 3.6 seconds for 10 profiles
# ____________________________________
# Biology (Barnard College)
# Time taken = 11.7 seconds for 20 profiles
# ____________________________________
# Biomedical Engineering Department
# Time taken = 4.1 seconds for 11 profiles
# ____________________________________
# Biostatistics Department
# Time taken = 15.9 seconds for 34 profiles
# ____________________________________
# Chemical Engineering Department
# Time taken = 3.8 seconds for 11 profiles
# ____________________________________
# Chemistry (Barnard College)
# Time taken = 4.8 seconds for 14 profiles
# ____________________________________
# Chemistry, Department of
# Time taken = 12.3 seconds for 35 profiles
# ____________________________________
# Civil Engineering and Engineering Mechanics Department
# Time taken = 3.8 seconds for 12 profiles
# ____________________________________
# Classics and Ancient Studies (Barnard College)
# No profiles
# ____________________________________
# Classics Department
# No profiles
# ____________________________________
# Computer Science Department
# Time taken = 12.3 seconds for 72 profiles
# ____________________________________
# Dance (Barnard College)
# Time taken = 6.9 seconds for 22 profiles
# ____________________________________
# Decision, Risk, and Operations Division
# Time taken = 50.5 seconds for 49 profiles
# ____________________________________
# Earth and Environmental Engineering Department
# Time taken = 3.6 seconds for 11 profiles
# ____________________________________
# Earth and Environmental Sciences Department
# Time taken = 24.9 seconds for 40 profiles
# ____________________________________
# East Asian Languages and Cultures Department
# No profiles
# ____________________________________
# Ecology, Evolution and Environmental Biology Department
# No profiles
# ____________________________________
# Economics (Barnard College)
# Time taken = 0.0 seconds for 17 profiles
# ____________________________________
# Economics Department
# Time taken = 15.9 seconds for 54 profiles
# ____________________________________
# Electrical Engineering Department
# Time taken = 14.1 seconds for 32 profiles
# ____________________________________
# English and Comparative Literature Department
# Time taken = 27.2 seconds for 60 profiles
# ____________________________________
# Environmental Health Sciences Department
# Time taken = 10.0 seconds for 31 profiles
# ____________________________________
# Environmental Science (Barnard College)
# Time taken = 4.9 seconds for 9 profiles
# ____________________________________
# Epidemiology Department
# Time taken = 2493.9 seconds for 93 profiles
# ____________________________________
# Film (School of the Arts)
# No profiles
# ____________________________________
# Finance and Economics Division
# Time taken = 60.5 seconds for 131 profiles
# ____________________________________
# French (Barnard College)
# Time taken = 1.9 seconds for 8 profiles
# ____________________________________
# French and Romance Philology Department
# Time taken = 6.6 seconds for 26 profiles
# ____________________________________
# Germanic Languages Department
# Time taken = 5.1 seconds for 23 profiles
# ____________________________________
# Health Policy and Management Department
# Time taken = 12.7 seconds for 94 profiles
# ____________________________________
# Hematology, Division of
# No profiles
# ____________________________________
# History Department
# No profiles
# ____________________________________
# Industrial Engineering & Operations Research, Department of
# Time taken = 3.0 seconds for 12 profiles
# ____________________________________
# Italian Department
# Time taken = 2.9 seconds for 11 profiles
# ____________________________________
# Latin American and Iberian Cultures, Department of
# No profiles
# ____________________________________
# Management Division
# No profiles
# ____________________________________
# Marketing Division
# Time taken = 48.7 seconds for 64 profiles
# ____________________________________
# Mathematics (Barnard College)
# Time taken = 2.2 seconds for 5 profiles
# ____________________________________
# Mathematics Department
# Time taken = 2.7 seconds for 15 profiles
# ____________________________________
# Mechanical Engineering Department
# Time taken = 2.9 seconds for 11 profiles
# ____________________________________
# Microbiology & Immunology, Department of
# No profiles
# ____________________________________
# Middle Eastern, South Asian, and African Studies
# Time taken = 8.2 seconds for 26 profiles
# ____________________________________
# Music, Department of
# Time taken = 10.8 seconds for 54 profiles
# ____________________________________
# Philosophy (Barnard College)
# Time taken = 0.0 seconds for 30 profiles
# ____________________________________
# Philosophy, Department of
# No profiles
# ____________________________________
# Physical Education (Barnard College)
# No profiles
# ____________________________________
# Physics and Astronomy (Barnard College)
# Time taken = 1.8 seconds for 7 profiles
# ____________________________________
# Physics, Department of
# Time taken = 9.1 seconds for 44 profiles
# ____________________________________
# Political Science (Barnard College)
# No profiles
# ____________________________________
# Political Science, Department of
# No profiles
# ____________________________________
# Population & Family Health, Heilbrunn Department of
# Time taken = 11.3 seconds for 85 profiles
# ____________________________________
# Psychology (Barnard College)
# Time taken = 2.0 seconds for 8 profiles
# ____________________________________
# Psychology, Department of
# Time taken = 10.8 seconds for 42 profiles
# ____________________________________
# Religion (Barnard College)
# Time taken = 0.0 seconds for 7 profiles
# ____________________________________
# Religion, Department of
# Time taken = 10.6 seconds for 33 profiles
# ____________________________________
# Slavic (Barnard College)
# No profiles
# ____________________________________
# Slavic Languages, Department of
# No profiles
# ____________________________________
# Sociology (Barnard College)
# Time taken = 1.2 seconds for 5 profiles
# ____________________________________
# Sociology, Department of
# Time taken = 10.2 seconds for 34 profiles
# ____________________________________
# Sociomedical Sciences, Department of
# Time taken = 14.6 seconds for 67 profiles
# ____________________________________
# Spanish and Latin American Cultures (Barnard College)
# No profiles
# ____________________________________
# Statistics, Department of
# Time taken = 10.9 seconds for 59 profiles
# ____________________________________
# Theatre (Barnard College)
# No profiles
# ____________________________________
# Theatre (School of the Arts)
# No profiles
# ____________________________________
# Visual Arts (School of the Arts)
# No profiles
# ____________________________________
# Writing (School of the Arts)
# No profiles
# ____________________________________

# %%
with open(sys.path[0] + '/../data/columbia_test_sans_processing_w_name_gender_race_img.json', 'w') as f:
    json.dump(columbia, f)
