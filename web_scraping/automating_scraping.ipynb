# %%
import requests 
from bs4 import BeautifulSoup 
import re
from statistics import mode
import pandas as pd
import numpy as np

# %% [markdown]
# ## Common functions

# %%
def get_soup(URL):
    r = requests.get(URL) 
    return BeautifulSoup(r.content, 'html5lib')

# %%
# return 3 images, to make sure images selected are the headshots 
def select_headshots(soup):
    headshots = soup.body.find_all('img')
    return headshots[len(headshots)//6], headshots[len(headshots)//3], headshots[len(headshots)//2]

# %%
# check if the link for imgs are src or srcset
def src_or_srcset(tag):
    try: 
        tag['src']
        return True
    except:
        return False

# %%
# possible to use ML instead of regex to find name?
def find_name_pos(tag):
    pos = 0
    strs = tag.stripped_strings
    while True: 
        s = next(strs)
        if re.match("^([a-zA-Z.]*[,]* [a-zA-Z.]* [a-zA-Z.]*|[a-zA-Z.]*[,]* [a-zA-Z.]*)[, Ph.D.]*$", s):
            if "University" not in s and "College" not in s and 'Department' not in s:
                return pos
        pos += 1

# %%
def find_title_pos(tag):
    pos = 0
    strs = tag.stripped_strings
    while True: 
        s = next(strs)
        if re.match("[a-zA-Z0-9 ]*(Professor|Lecturer|Student|Director)[a-zA-Z0-9_ ]*", s):
            return pos
        else:
            pos += 1

# %%
def find_by_pos(tag, pos):
    it = tag.stripped_strings
    try:
        item = next(x for i,x in enumerate(it) if i==pos)
    except:
        item = None
    return item

# %%
def find_img(tag, src):
    try:
        if src:
            img = tag.find('img')['src']
        else:
            img = tag.find('img')['srcset'].split()[0]
    except:
        img = None
    return img

# %% [markdown]
# ## Using class name

# %%
# for each tag containing imgs, find their first parents that contains the the keyword 
# (professor, lecturer, student (some pages include grad students), ...) 
# My rational is since the tag includes the title already, it likely also includes the name of the person. 

def find_profile_class(tag):
    s = str(tag)
    if re.search(r'(Professor|Lecturer|Student|Director)', s):
        m = re.findall(r'class="(.+?)"', s)
        return tag, m[0]
    else:
        return find_profile_class(tag.parent)

# %%
def get_department_info_class_name(URL):
    # get the soup (entire webpage)
    soup = get_soup(URL)
    
    # get 3 headshot tags in different pos. Because all the pages have headshots ('img' in html), 
    # that's something in common for all pages regardless of the design 
    headshots = select_headshots(soup)
    
    # use the random headshot to find the name of the class containing profiles, name pos and title pos
    profile_classes = []
    tags = []
    src_or_not = None
    
    # for each tag containing imgs, find their first parents that contains the the keyword 
    # (professor, lecturer, student (some pages include grad students), ...) 
    # My rational is since the tag includes the title already, it likely also includes the name of the person. 
    for headshot in headshots:
        tag, profile_c = find_profile_class(headshot)
        profile_classes.append(profile_c)
        tags.append(tag)
        
    # compare the class name of tag containg profile found from ancestors of the 3 headshot tags, 
    # if 2 or more out of 3 are same, select it as the class name of profile tags. If all 3 are different, throw an error
    if len(set(profile_classes)) != 3:
        if profile_classes[0] == profile_classes[1] or profile_classes[0] == profile_classes[2]:
            profile_class = profile_classes[0]
            tmp_tag = tags[0]
            src_or_not = src_or_srcset(headshots[0])
        else:
            profile_class = profile_classes[1]
            tmp_tag = tags[1]
            src_or_not = src_or_srcset(headshots[1])
    else:
        raise Exception("class names for profiles are different")

    # find the position of name and title in the tmp_tag (from 1 of parents of headshots)
    name_pos = find_name_pos(tmp_tag)
    title_pos = find_title_pos(tmp_tag)

    
    # get all profiles
    profs = soup.find_all(attrs = {'class':profile_class})
    items = []
    # get info for each profile
    for p in profs:
        name = find_by_pos(p, name_pos)
        title = find_by_pos(p, title_pos)
        img = find_img(p, src_or_not)
        item = {'name': name, 'title': title, 'img':img}
        items.append(item)
    return items

# %% [markdown]
# ## Using siblings

# %%
# similar to class name in using recursion, but get all the profiles using siblings instead
def find_profile_siblings(tag):
    s = str(tag)
    if re.search(r'(Professor|Lecturer|Student|Director)', s):
        tags = []
        p_siblings = tag.previous_siblings
        n_siblings = tag.next_siblings
        tags.extend(list(p_siblings))
        tags.append(tag)
        tags.extend(n_siblings)
        return (tag, tags)
    else:
        return find_profile_siblings(tag.parent)

# %%
def get_department_info_siblings(URL):
    # get the soup (entire webpage)
    soup = get_soup(URL)
    
    # get 3 headshot tags in different pos. Because all the pages have headshots ('img' in html), 
    # that's something in common for all pages regardless of the design 
    headshots = select_headshots(soup)
    
    # use the random headshot to find the name of the class containing profiles, name pos and title pos
    tmp_tags = []
    lsts_tags = []
    src_or_not = None
    
    for headshot in headshots:
        tmp_tag, lst_tags = find_profile_siblings(headshot)
        tmp_tags.append(tmp_tag)
        lsts_tags.append(lst_tags)
        
    # choose the longest list
    if len(lsts_tags[0]) >= len(lsts_tags[1]) and len(lsts_tags[0]) >= len(lsts_tags[2]):
        tmp_tag = tmp_tags[0]
        profs = lsts_tags[0]
        src_or_not = src_or_srcset(headshots[0])
    elif len(lsts_tags[1]) >= len(lsts_tags[0]) and len(lsts_tags[1]) >= len(lsts_tags[2]):
        tmp_tag = tmp_tags[1]
        profs = lsts_tags[1]
        src_or_not = src_or_srcset(headshots[1])
    else:
        tmp_tag = tmp_tags[2]
        profs = lsts_tags[2]
        src_or_not = src_or_srcset(headshots[2])

        
    # find the position of name and title in the tmp_tag (from 1 of parents of headshots)
    name_pos = find_name_pos(tmp_tag)
    title_pos = find_title_pos(tmp_tag)

    items = []
    # get info for each profile
    for p in profs:
        name = find_by_pos(p, name_pos)
        title = find_by_pos(p, title_pos)
        img = find_img(p, src_or_not)
        item = {'name': name, 'title': title, 'img':img}
        items.append(item)
    return items

# %%
get_department_info_siblings("https://www.brown.edu/academics/math/faculty")
# Out:
# [{'name': 'George Daskalopoulos',
#   'title': 'Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/George.jpg'},
#  {'name': 'Melody Chan',
#   'title': 'Associate Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Melody.jpg'},
#  {'name': 'Christine Breiner',
#   'title': 'Associate\xa0Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Christine.png'},
#  {'name': 'Madeline Brandt',
#   'title': 'Tamarkin Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Brandt.png'},
#  {'name': 'Dan Abramovich',
#   'title': 'L. Herbert Ballou University Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Abramovich_1.jpg'},
#  {'name': 'Charles Daly',
#   'title': 'Tamarkin Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Screen%20Shot%202021-07-15%20at%2010.44.28%20AM.png'},
#  {'name': 'S. James Gates',
#   'title': 'Ford Foundation Professor of Physics',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Gates.jpg'},
#  {'name': 'Thomas Goodwillie',
#   'title': 'Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Goodwillie.jpg'},
#  {'name': 'Brendan Hassett',
#   'title': 'Professor, Director of ICERM',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Hassett.jpg'},
#  {'name': 'Susanna Haziot',
#   'title': 'Tamarkin Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Screen%20Shot%202021-07-19%20at%2010.01.55%20AM_0.png'},
#  {'name': 'Jeffrey Hoffstein',
#   'title': 'Professor, Chair',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Hoffstein_0.jpg'},
#  {'name': 'Justin Holmer',
#   'title': 'Associate Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Holmer_2021_0.jpg'},
#  {'name': 'Yu-Wen Hsu',
#   'title': 'Lecturer',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Hsu.jpg'},
#  {'name': 'Yajit Jain',
#   'title': 'Tamarkin Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Jain_Portrait_0.jpg'},
#  {'name': 'Junehyuk Jung',
#   'title': 'Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Jung.jpg'},
#  {'name': 'Jeremy Kahn',
#   'title': 'Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Kahn.jpg'},
#  {'name': 'Nicolaos\xa0Kapouleas',
#   'title': 'Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Nicos.jpg'},
#  {'name': 'Daniel Katz',
#   'title': 'Senior\xa0Lecturer',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Katz_0.jpg'},
#  {'name': 'Jordan Kostiuk',
#   'title': 'Lecturer',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Kostiuk.jpg'},
#  {'name': 'Alan Landman',
#   'title': 'Associate Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/landman_0.png'},
#  {'name': 'Eric Larson',
#   'title': 'Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Larson_0.jpg'},
#  {'name': 'Jungang Li',
#   'title': 'Tamarkin Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Jungang.jpg'},
#  {'name': 'Nicole Looper',
#   'title': 'Drs. Ruth and Howard Triedman Tamarkin Assistant Professor of Mathematics',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Looper.jpg'},
#  {'name': 'Benoit Pausader',
#   'title': 'Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Pausader.jpg'},
#  {'name': 'Jill Pipher',
#   'title': 'Elisha Benjamin Andrews Professor of Mathematics',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Pipher.jpg'},
#  {'name': 'Richard Schwartz',
#   'title': "Chancellor's Professor of Mathematics",
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Schwartz.jpg'},
#  {'name': 'Joseph Silverman',
#   'title': 'Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Silverman_2021.jpg'},
#  {'name': 'Yuri Sulyma',
#   'title': 'Tamarkin Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Sulyma.jpg'},
#  {'name': 'Sergei Treil',
#   'title': 'Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Treil.jpg'},
#  {'name': 'Bena Tshishiku',
#   'title': 'Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Bena.jpg'},
#  {'name': 'Jeremy Usatine',
#   'title': 'Tamarkin Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/Usatine.jpg'},
#  {'name': 'Isabel Vogt',
#   'title': 'Assistant Professor',
#   'img': 'https://www.brown.edu/academics/math/sites/math/files/IVogt.png'}]

# %% [markdown]
# ## Testing

# %%
urls = ["https://stat.columbia.edu/department-directory/faculty-and-lecturers/", 
         "https://statistics.wharton.upenn.edu/faculty/faculty-list/",
         "https://statistics.fas.harvard.edu/faculty",
         "https://statistics.yale.edu/people",
         "https://www.brown.edu/academics/public-health/biostats/people/faculty",
         "https://stat.cornell.edu/people/faculty",
         "https://www.math.columbia.edu/people/faculty-by-rank/",
         "https://www.math.upenn.edu/people/standing-faculty",
         "https://www.math.harvard.edu/people/",
         "https://math.yale.edu/people/all-faculty",
         "https://www.brown.edu/academics/math/faculty"
        ]

# %%
class_name_works = []
class_name_fails = []

siblings_works = []
siblings_fails = []

for url in urls:
    # try class name
    try:
        res = get_department_info_class_name(url)
        item = {'url': url, 'res':res}
        class_name_works.append(item)
    except:
        class_name_fails.append(url)
        
    try:
        res = get_department_info_siblings(url)
        item = {'url': url, 'res':res}
        siblings_works.append(item)
    except:
        siblings_fails.append(url)

# %%
class_name_fails
# Out:
# ['https://stat.cornell.edu/people/faculty',
#  'https://www.brown.edu/academics/math/faculty']

# %%
siblings_fails
# Out:
# []

# %%
for i in class_name_works:
    print("________________________________________________________________________________________________________")
    print(f"url: {i.get('url')}")
    res = i.get('res')
    print(f"length: {len(res)}")
    print("___________")
    print(res[0])
    print(res[len(res)//2])
    print(res[-1])
# Out:
# ________________________________________________________________________________________________________
# url: https://stat.columbia.edu/department-directory/faculty-and-lecturers/
# length: 60
# ___________
# {'name': 'David Blei', 'title': 'Professor', 'img': 'https://stat.columbia.edu/wp-content/uploads/connections-images/david-blei/Blei-David-1.jpg'}
# {'name': 'Banu Baydil', 'title': 'Lecturer in Discipline, Co-Director of M.A. Programs', 'img': 'https://stat.columbia.edu/wp-content/uploads/connections-images/banu-baydil/banu_original.jpg'}
# {'name': 'Rongning Wu', 'title': 'Adjunct Assistant Professor', 'img': None}
# ________________________________________________________________________________________________________
# url: https://statistics.wharton.upenn.edu/faculty/faculty-list/
# length: 52
# ___________
# {'name': 'Bhaswar B. Bhattacharya', 'title': 'Assistant Professor of Statistics and Data Science', 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2016/09/Bhaswar_Homepage_Cropped.jpg'}
# {'name': 'Mingyao Li', 'title': 'Professor of Biostatistics, Professor of Statistics and Data Science', 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2016/11/MingyaoLi.jpg'}
# {'name': 'Larry A. Shepp', 'title': 'Professor of Statistics', 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2012/04/Larryshepp.JPG'}
# ________________________________________________________________________________________________________
# url: https://statistics.fas.harvard.edu/faculty
# length: 34
# ___________
# {'name': 'Morgane Austern', 'title': 'Assistant Professor', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/img-20210401-wa0022.jpg?m=1647356154&itok=X-5OHRTO'}
# {'name': 'Neil Shephard', 'title': 'Chair of Department of Statistics,', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/shephard.jpg?m=1629481859&itok=dHZz9R46'}
# {'name': 'Alexander Young', 'title': '(He / him / his)', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/alex_young.jpg?m=1630084986&itok=f2GUkkkg'}
# ________________________________________________________________________________________________________
# url: https://statistics.yale.edu/people
# length: 109
# ___________
# {'name': 'Andrew Barron', 'title': 'Charles C. and Dorothea S. Dilley Professor of Statistics & Data Science', 'img': 'https://statistics.yale.edu/sites/default/files/styles/people_user_image/public/pictures/picture-15-1362597227.jpg?itok=sPNt5_6y'}
# {'name': 'Soham Jana', 'title': 'Graduate School Student', 'img': 'https://statistics.yale.edu/sites/default/files/styles/people_user_image/public/pictures/picture-496-1516980113.jpg?itok=u8CruYhp'}
# {'name': 'Elizavette Torres', 'title': 'Event Coordinator and Faculty Support', 'img': 'https://statistics.yale.edu/sites/default/files/styles/people_user_image/public/pictures/picture-56-1506962214.jpg?itok=_yx2L5Re'}
# ________________________________________________________________________________________________________
# url: https://www.brown.edu/academics/public-health/biostats/people/faculty
# length: 18
# ___________
# {'name': 'Alyssa Bilinski, Ph.D.', 'title': 'Peterson Family Assistant Professor of Health Policy, Assistant Professor of Health Services, Policy and Practice and Biostatistics', 'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/abilinsk_photo_.jpg'}
# {'name': 'Youjin  Lee, Ph.D.', 'title': 'Manning Assistant Professorship of Biostatistics', 'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/YoujinLee.jpg'}
# {'name': 'Zhijin (Jean)  Wu, Ph.D.', 'title': 'Professor of Biostatistics, Director of the Doctoral Graduate Program in Biostatistics', 'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Z%20Wu100.jpg'}
# ________________________________________________________________________________________________________
# url: https://www.math.columbia.edu/people/faculty-by-rank/
# length: 89
# ___________
# {'name': 'New York', 'title': 'Professor', 'img': '//www.math.columbia.edu/department/website/wp-content/uploads/connections-images/mohammed-abouzaid/abouzaid_original-4f5f03379ff345dc53d8afd47027fbab.jpg'}
# {'name': 'New York', 'title': 'Joseph F. Ritt Assistant Professor', 'img': '//www.math.columbia.edu/department/website/wp-content/uploads/connections-images/marco-castronovo/MarcoCastronovo-0a6ca663317b485cfdc948dded1dd468.jpeg'}
# {'name': '2990 Broadway', 'title': 'No Photo Available', 'img': None}
# ________________________________________________________________________________________________________
# url: https://www.math.upenn.edu/people/standing-faculty
# length: 40
# ___________
# {'name': 'Jonathan  Block', 'title': 'Professor of Mathematics', 'img': 'https://www.math.upenn.edu/sites/default/files/styles/profile-thumb/public/Block_0.jpg?itok=8lsKofiB'}
# {'name': 'Alexandre  Kirillov', 'title': 'Professor of Mathematics Emeritus', 'img': 'https://www.math.upenn.edu/sites/default/files/styles/profile-thumb/public/kirillov.jpg?itok=Ybv9xuBC'}
# {'name': 'Wolfgang  Ziller', 'title': 'Professor of Mathematics Emeritus', 'img': 'https://www.math.upenn.edu/sites/default/files/styles/profile-thumb/public/Ziller.jpg?itok=jZJNBmUo'}
# ________________________________________________________________________________________________________
# url: https://www.math.harvard.edu/people/
# length: 157
# ___________
# {'name': 'Alpöge, Levent', 'title': 'Junior Fellow', 'img': 'https://www.math.harvard.edu/wp-content/uploads/Levent_Alpoge.jpeg'}
# {'name': 'Kural, Michael', 'title': 'Graduate Student', 'img': 'https://www.math.harvard.edu/wp-content/uploads/Michael-Kural.jpg'}
# {'name': 'Yefremova, Anastasia', 'title': 'Publications Coordinator', 'img': 'https://www.math.harvard.edu/wp-content/uploads/Anastasia-Yefremova.jpg'}
# ________________________________________________________________________________________________________
# url: https://math.yale.edu/people/all-faculty
# length: 70
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': 'Nicholas Read', 'title': 'Henry Ford II Professor of Physics and Professor of Applied Physics and of Mathematics', 'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-636-1512665064.jpg?itok=zFNGCvyH'}
# {'name': 'Facebook', 'title': 'Twitter', 'img': None}

# %%
# https://www.math.columbia.edu/people/faculty-by-rank/ 
# and https://math.yale.edu/people/all-faculty also doesn't work
class_name_fails.append("https://www.math.columbia.edu/people/faculty-by-rank/")
class_name_fails.append("https://math.yale.edu/people/all-faculty")

# %%
for i in siblings_works:
    print("________________________________________________________________________________________________________")
    print(f"url: {i.get('url')}")
    res = i.get('res')
    print(f"length: {len(res)}")
    print("___________")
    print(res[0])
    print(res[len(res)//2])
    print(res[-1])
# Out:
# ________________________________________________________________________________________________________
# url: https://stat.columbia.edu/department-directory/faculty-and-lecturers/
# length: 5
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# ________________________________________________________________________________________________________
# url: https://statistics.wharton.upenn.edu/faculty/faculty-list/
# length: 17
# ___________
# {'name': 'Shane T. Jensen', 'title': 'Professor of Statistics and Data Science', 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2012/04/Jensen_shane.jpg'}
# {'name': 'Zongming Ma', 'title': 'Associate Professor of Statistics and Data Science, Statistics PhD Coordinator for Admissions', 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2016/11/ZongmingMa.jpg'}
# {'name': 'Linda Zhao', 'title': "Professor of Statistics and Data Science, Academic Director of the Dual Master's Degree in Statistics", 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2012/04/Lzhao.gif'}
# ________________________________________________________________________________________________________
# url: https://statistics.fas.harvard.edu/faculty
# length: 38
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# ________________________________________________________________________________________________________
# url: https://statistics.yale.edu/people
# length: 3
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': 'Dan Spielman', 'title': 'Sterling Professor of Computer Science and Statistics & Data Science and Mathematics', 'img': 'https://statistics.yale.edu/sites/default/files/styles/people_user_image/public/pictures/picture-446-1503516286.jpg?itok=WiyH_hY9'}
# {'name': None, 'title': None, 'img': None}
# ________________________________________________________________________________________________________
# url: https://www.brown.edu/academics/public-health/biostats/people/faculty
# length: 37
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# ________________________________________________________________________________________________________
# url: https://stat.cornell.edu/people/faculty
# length: 59
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': 'Kengo Kato', 'title': 'Professor', 'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/kato%20kengo.jpg?itok=JDh9_Hq9'}
# {'name': None, 'title': None, 'img': None}
# ________________________________________________________________________________________________________
# url: https://www.math.columbia.edu/people/faculty-by-rank/
# length: 3
# ___________
# {'name': None, 'title': 'Dorian', 'img': None}
# {'name': None, 'title': None, 'img': None}
# {'name': 'New York', 'title': 'Professor', 'img': '//www.math.columbia.edu/department/website/wp-content/uploads/connections-images/dorian-goldfeld/faculty1_original_2-d98e401ded62c278fcb882cd3f89afa6.jpg'}
# ________________________________________________________________________________________________________
# url: https://www.math.upenn.edu/people/standing-faculty
# length: 81
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# ________________________________________________________________________________________________________
# url: https://www.math.harvard.edu/people/
# length: 637
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# {'name': None, 'title': None, 'img': None}
# ________________________________________________________________________________________________________
# url: https://math.yale.edu/people/all-faculty
# length: 43
# ___________
# {'name': None, 'title': None, 'img': None}
# {'name': 'Andrew Neitzke', 'title': 'Director of Undergraduate Studies and Professor of Mathematics', 'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1410-1563285633.jpg?itok=N9TzZDMy'}
# {'name': None, 'title': None, 'img': None}
# ________________________________________________________________________________________________________
# url: https://www.brown.edu/academics/math/faculty
# length: 32
# ___________
# {'name': 'George Daskalopoulos', 'title': 'Professor', 'img': 'https://www.brown.edu/academics/math/sites/math/files/George.jpg'}
# {'name': 'Nicolaos\xa0Kapouleas', 'title': 'Professor', 'img': 'https://www.brown.edu/academics/math/sites/math/files/Nicos.jpg'}
# {'name': 'Isabel Vogt', 'title': 'Assistant Professor', 'img': 'https://www.brown.edu/academics/math/sites/math/files/IVogt.png'}

# %%
siblings_works[-2]
# Out:
# {'url': 'https://math.yale.edu/people/all-faculty',
#  'res': [{'name': None, 'title': None, 'img': None},
#   {'name': 'Vincent Moncrief',
#    'title': 'Professor of Physics and of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-246-1524160789.jpg?itok=7uaP4ADd'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Yair Minsky',
#    'title': 'Einar Hille Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-286-1512077508.jpg?itok=agFFE8ZQ'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Ivan Loseu',
#    'title': 'Director of Graduate Studies, Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1399-1562000240.jpg?itok=_iXuFibC'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Richard Kenyon',
#    'title': 'Erastus L. DeForest Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1408-1565277180.jpg?itok=KgZEIaGP'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Peter Jones',
#    'title': 'James E. English Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-216-1512665676.jpg?itok=pbs4TwgI'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Alexander Goncharov',
#    'title': 'Philip Schuyler Beebe Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-206-1524231611.jpg?itok=qqfxQUUT'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Anna Gilbert',
#    'title': 'John C. Malone Professor of Mathematics and of Statistics and Data Science',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1481-1593791235.jpg?itok=fa5SR_2z'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Igor Frenkel',
#    'title': 'Sol Goldman Family Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-236-1512662000.jpg?itok=yGZGsU6r'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Ronald Coifman',
#    'title': 'Sterling Professor of Mathematics and Professor of Computer Science',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-416-1512666292.jpg?itok=9K1P7X--'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Jeffrey Brock',
#    'title': 'Dean, School of Engineering & Applied Science; FAS Dean of Science; Zhao and Ji Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-886-1590976044.jpg?itok=wJR25f-W'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Andrew Neitzke',
#    'title': 'Director of Undergraduate Studies and Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1410-1563285633.jpg?itok=N9TzZDMy'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Hee Oh',
#    'title': 'Abraham Robinson Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-266-1584491885.jpg?itok=mQ3IZ3qU'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Nicholas Read',
#    'title': 'Henry Ford II Professor of Physics and Professor of Applied Physics and of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-636-1512665064.jpg?itok=zFNGCvyH'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Vladimir Rokhlin',
#    'title': 'Arthur K. Watson Professor of Computer Science and Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-226-1512667250.jpg?itok=FW0xl4S8'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Wilhelm Schlag',
#    'title': 'Phillips Professor of Mathematics, Department Chair',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-971-1626119480.jpg?itok=0RHONYpR'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'John Schotland',
#    'title': 'Professor of Mathematics and Professor of Physics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1476-1591807825.jpg?itok=YwGP_1J3'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Charles Smart',
#    'title': 'Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1543-1625163484.jpg?itok=eJOCIrhd'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Dan Spielman',
#    'title': 'Sterling Professor of Computer Science and Professor of Statistics and Data Science and of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-316-1512655980.jpg?itok=OjF4bRIM'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Van Vu',
#    'title': 'Percey F. Smith Professor of Mathematics and Professor of Statistics & Data Science',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-306-1559583859.jpg?itok=Z3HQ_8Mm'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'Lu Wang',
#    'title': 'Professor of Mathematics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1529-1625163833.jpg?itok=gjavAtHQ'},
#   {'name': None, 'title': None, 'img': None},
#   {'name': 'John Wettlaufer',
#    'title': 'A.M. Bateman Professor of Geophysics, Mathematics and Physics',
#    'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-731-1512663218.jpg?itok=NtlCX2-P'},
#   {'name': None, 'title': None, 'img': None}]}
