# %%
import requests 
from bs4 import BeautifulSoup 
import re
from statistics import mode
import unidecode

# %% [markdown]
# ## Common functions

# %%
def get_soup(URL):
    r = requests.get(URL) 
    soup = BeautifulSoup(r.content, 'html5lib')
    return soup.body

# %%
def select_headshots(soup):
    headshots = soup.find_all('img')
    if len(headshots) < 3:
        raise Exception("Not enough imgs")
    elif len(headshots) < 10:
        items = [headshots[len(headshots)//3], headshots[len(headshots)//3*2], headshots[len(headshots)-2]]
    elif len(headshots) > 50:
        items = [headshots[len(headshots)//10*i] for i in range(1,10)]
    else:
        items = [headshots[len(headshots)//7*i] for i in range(1,7)]
    return items

# %%
# check if the link for imgs are src or srcset
def src_or_srcset(tag):
    try:
        tag['src']
        return True
    except:
        return False

# %%
def find_name_pos(tag):
    pos = 0
    strs = tag.stripped_strings
    while True:
        try:
            s = next(strs)
            if re.match("^([a-zA-Z\.\-]*[,]* [a-zA-Z\.]* [a-zA-Z\.\-]*|[a-zA-Z\.\-]*[,]* [a-zA-Z\.\-]*)[, Ph\.D\.]*$",
                      unidecode.unidecode(" ".join(s.split()))):
                if "University" not in s and "College" not in s and "Department" not in s\
                and "Faculty" not in s and "Research" not in s and "Interest" not in s and "Profile" not in s:
                    return pos
            pos += 1
        except:
            raise Exception("name position not found")

# %%
def find_title_pos(tag):
    pos = 0
    strs = tag.stripped_strings
    while True:
        try:
            s = next(strs)
            if re.match("(?i).*(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|PhD).*", s):
                return pos
            else:
                pos += 1
        except:
            raise Exception("title position not found")

# %%
def find_pos(tags):
    name_positions = []
    title_positions = []
    for tag in tags:
        try:
            name_pos = find_name_pos(tag)
            title_pos = find_title_pos(tag)
            name_positions.append(name_pos)
            title_positions.append(title_pos)
        except:
            pass
        
    if len(name_positions) == 0:
        raise Exception("failed to find positions")
    name_pos = mode(name_positions)
    title_pos = mode(title_positions)
    return name_pos, title_pos

# %%
def is_name(s):
    if s is None:
        return None
    elif re.match("^([a-zA-Z\.\-]*[,]* [a-zA-Z\.]* [a-zA-Z\.\-]*|[a-zA-Z\.\-]*[,]* [a-zA-Z\.\-]*)[, Ph\.D\.]*$",
                  unidecode.unidecode(" ".join(s.split()))):
        return s
    else:
        return None

# %%
def is_title(s):
    if s is None:
        return None
    elif re.match("(?i).*(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|PhD).*", s):
        return s
    else:
        return None

# %%
def find_by_pos(tag, pos):
    it = tag.stripped_strings
    try:
        item = next(x for i,x in enumerate(it) if i==pos)
    except:
        item = None
    return item

# %%
def find_img(tag, src):
    try:
        if src:
            img = tag.find('img')['src']
        else:
            img = tag.find('img')['srcset'].split()[0]
    except:
        pass
    
    img_tag = tag.find('img')
    if img_tag is not None:
        if src:
            img = img_tag['src']
        else:
            img = img_tag['srcset'].split()[0]
    else:
        img = None
    return img

# %%
def get_info(profs, name_pos, title_pos, src_or_not):
    items = []
    total = 0
    no_fails = 0
    for p in profs:
        name = find_by_pos(p, name_pos)
        #name = is_name(name)
        title = find_by_pos(p, title_pos)
        #title = is_title(title)
        img = find_img(p, src_or_not)
        if name is not None and title is not None:
            item = {'name': name, 'title': title, 'img':img}
            items.append(item)
            total += 1
            if name is None or title is None:
                no_fails += 1
    if no_fails/total > 1/3 or total < 5:
        raise Exception("FAILED")
    return items

# %% [markdown]
# ## Using tr

# %%
def find_profs_tr(soup):
    profs = soup.find_all('tr')
    if len(profs) == 0:
        raise Exception("No tr")
    else:
        return profs

# %%
def get_department_info_tr(URL):
    # get the soup (entire webpage)
    soup = get_soup(URL)

    profs = find_profs_tr(soup)
    
    src_or_not = None
    while src_or_not is None:
        if tag.find('img'):
            img_tag = tag.find('img')
            src_or_not = src_or_srcset(img_tag)
            
    tags = [profs[len(profs)//5*i] for i in range(1,6)]

    name_pos, title_pos = find_pos(tags)
        
    items = get_info(profs, name_pos, title_pos, src_or_not)
    return items

# %% [markdown]
# ## Using class name

# %%
# for each tag containing imgs, find their first parents that contains the the keyword 
# (professor, lecturer, student (some pages include grad students), ...) 
# My rational is since the tag includes the title already, it likely also includes the name of the person. 

def find_profile_class(tag, levels_allowed):
    if levels_allowed == 0:
        raise Exception("Class name not found")
    s = ' '.join(list(tag.stripped_strings))
    if re.search(r"(?i)(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|PhD|Dean|Senior|Preceptor)", s):
        tag_s = str(tag)
        m = re.findall(r'class="(.+?)"', tag_s)
        # allow going up 2 more levels if 'class=' is not found 
        if len(m) == 0:
            return find_profile_class(tag.parent, levels_allowed - 1)
        else:
            return tag, m[0]
    else:
        return find_profile_class(tag.parent, levels_allowed)

# %%
def get_department_info_class(URL):
    soup = get_soup(URL)
    
    headshots = select_headshots(soup)
    src_or_not = src_or_srcset(headshots[0])

    profile_classes = []
    tags = []
    for headshot in headshots:
        try:
            tag, profile_c = find_profile_class(headshot, 2)
            profile_classes.append(profile_c)
            tags.append(tag)
        except:
            pass
        
    if len(profile_classes) == 0:
        raise Exception("class name not found")
    elif len(set(profile_classes)) == len(profile_classes):
        raise Exception("class names for profiles are different")
    else:
        profile_class = mode(profile_classes)
    
    tags = [t for (t, c) in zip(tags, profile_classes) if c == profile_class]
    name_positions = []
    title_positions = []
    for (tag,p_name) in zip(tags, profile_classes):
        if p_name == profile_class:
            try:
                name_pos = find_name_pos(tag)
                title_pos = find_title_pos(tag)
                name_positions.append(name_pos)
                title_positions.append(title_pos)
            except:
                pass
    
    if len(name_positions) == 0:
        raise Exception("failed to find positions")
    name_pos = mode(name_positions)
    title_pos = mode(title_positions)
    
    profs = soup.find_all(attrs = {'class':profile_class})

    items = get_info(profs, name_pos, title_pos, src_or_not)
    return items

# %% [markdown]
# # children

# %%
def find_profile_children(tags):
    parents = []
    parent = None
    while parent is None:
        new_tags = []
        for tag in tags:
            tmp_parent = tag.parent
            if tmp_parent in parents:
                target_tag = tag
                parent = tmp_parent
                break
            else:
                parents.append(tmp_parent)
                new_tags.append(tmp_parent)
        tags = new_tags
            
    
    tag_name = target_tag.name
    children = parent.findChildren(recursive=False)
    items = []
    for c in children:
        if c.name == tag_name:
            items.append(c)
    return items

# %%
def get_department_info_children(URL):
    # get the soup (entire webpage)
    soup = get_soup(URL)
    
    headshots = select_headshots(soup)
        
    profs = find_profile_children(headshots)
    src_or_not = src_or_srcset(headshots[0])
    
    tags = []
    for h in headshots:
        for p in profs:
            if str(h) in str(p):
                tags.append(p)
                break
    tags = list(set(tags))
    if len(tags) / len(headshots) < 2/3:
        raise Exception("children failed")
    
    name_positions = []
    title_positions = []
    for tag in tags:
        try:
            name_pos = find_name_pos(tag)
            title_pos = find_title_pos(tag)
            name_positions.append(name_pos)
            title_positions.append(title_pos)
        except:
            pass

    if len(name_positions) == 0:
        raise Exception("failed to find positions")
    name_pos = mode(name_positions)
    title_pos = mode(title_positions)

    items = get_info(profs, name_pos, title_pos, src_or_not)
    return items

# %% [markdown]
# ## Brute Force

# %%
def find_profile_bf(tag, count):
    s = ' '.join(list(tag.stripped_strings))
    if re.search(r"(?i)(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|PhD|Dean|Senior|Preceptor)", s):
        return tag, count
    else:
        count = count + 1
        return find_profile_bf(tag.parent, count)

# %%
def get_department_info_bf(URL):
    soup = get_soup(URL)
    
    headshots = select_headshots(soup)
    src_or_not = src_or_srcset(headshots[0])
    
    counts = []
    tags = []
    for headshot in headshots:
        try:
            tag, count = find_profile_bf(headshot, 0)
            counts.append(count)
            tags.append(tag)
        except:
            pass
    
    
    if len(counts) == 0:
        raise Exception("bf failed")
    elif len(set(counts)) == len(counts):
        raise Exception("counts are all different")
    else:
        count = mode(counts)
    
    name_positions = []
    title_positions = []
    for (tag, c) in zip(tags, counts):
        if c == count:
            try:
                name_pos = find_name_pos(tag)
                title_pos = find_title_pos(tag)
                name_positions.append(name_pos)
                title_positions.append(title_pos)
            except:
                pass
    
    if len(name_positions) == 0:
        raise Exception("failed to find positions")
    name_pos = mode(name_positions)
    title_pos = mode(title_positions)
    
    all_headshots = soup.find_all('img')
    profs = []
    for t in all_headshots:
        for i in range(count):
            t = t.parent
        profs.append(t)
    items = get_info(profs, name_pos, title_pos, src_or_not)
    return items

# %% [markdown]
# ## Testing

# %%
url = "https://arts.columbia.edu/film/faculty"
soup = get_soup(url)

# %%
t = soup.find_all('div',style=lambda value: value and 'background-image' in value)[0]
url = re.findall('\((.*?)\)', t['style'])[0]

# %%
url
# Out:
# 'https://arts.columbia.edu/sites/arts.columbia.edu/files/film_hs_apetri_bogdan_2.jpeg'

# %%
bf_works = []
bf_fails = []
for url in urls[:10]:
    try:
        res = get_department_info_bf(url)
        item = {'url': url, 'res':res}
        bf_works.append(item)
    except:
        bf_fails.append(url)

# %%
children_works = []
children_fails = []
for url in urls[:10]:
    try:
        res = get_department_info_children(url)
        item = {'url': url, 'res':res}
        children_works.append(item)
    except:
        children_fails.append(url)

# %%
children_works
# Out:
# [{'url': 'https://statistics.fas.harvard.edu/faculty',
#   'res': [{'name': 'Morgane Austern',
#     'title': 'Assistant Professor',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/img-20210401-wa0022.jpg?m=1647356154&itok=X-5OHRTO'},
#    {'name': 'Joseph K. Blitzstein',
#     'title': 'Professor of the Practice in Statistics,',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/blitzstein_1_0.jpg?m=1629481923&itok=K83gCeQ4'},
#    {'name': 'Stephen Blyth',
#     'title': 'Professor of the Practice in Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/blyth_1.jpg?m=1626193422&itok=ZmDqLNx4'},
#    {'name': 'Mark E. Glickman',
#     'title': 'Senior Lecturer in Statistics,',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/glickman_resize.jpg?m=1597767942&itok=kwDV0EHW'},
#    {'name': 'Kosuke Imai',
#     'title': 'Professor of Government and Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/imaiwhiteboard_01.png?m=1626193461&itok=ke4QW3ms'},
#    {'name': 'Lucas Janson',
#     'title': '(He / him / his)',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/lucas_janson.jpg?m=1630086689&itok=6-zQaOUq'},
#    {'name': 'Sham Kakade',
#     'title': '(He, him, his)',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/rsz_5photo_kakade.jpg?m=1641236499&itok=pPM63U0G'},
#    {'name': 'Tracy Ke',
#     'title': 'Assistant Professor of Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/ke_tracy.jpg?m=1560437906&itok=BCeEy-mo'},
#    {'name': 'S.C. Samuel Kou',
#     'title': 'Professor of Statistics,',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/rsz_kou.jpg?m=1561993086&itok=dK6Eby8F'},
#    {'name': 'Xihong Lin',
#     'title': 'Professor of Statistics,',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/lin-2015.jpg?m=1636471482&itok=OkR6bNgP'},
#    {'name': 'Jun S. Liu',
#     'title': 'Professor of Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/liu_01.jpg?m=1630613490&itok=05uNHfV1'},
#    {'name': 'Kelly McConville',
#     'title': 'Senior Lecturer in Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/kelly-mcconville-2.jpg?m=1641915453&itok=IsXBykyy'},
#    {'name': 'Xiao-Li Meng',
#     'title': 'Whipple V. N. Jones Professor of Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/meng.jpg?m=1653251823&itok=EYTJAMsX'},
#    {'name': 'Susan Murphy',
#     'title': 'Mallinckrodt Professor of Statistics and of Computer Science,',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/susan_murphy_jpg_web.jpg?m=1631022333&itok=XafNLajf'},
#    {'name': 'Natesh S. Pillai',
#     'title': 'Professor of Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/pillai.jpg?m=1630613575&itok=7cAUavTz'},
#    {'name': 'Kevin Rader',
#     'title': 'Senior Preceptor in Statistics,',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/rader.jpg?m=1630613609&itok=y38IEcAG'},
#    {'name': 'Subhabrata Sen',
#     'title': 'Assistant Professor of Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/sen.jpg?m=1630613628&itok=NXuItqAf'},
#    {'name': 'Neil Shephard',
#     'title': 'Chair of Department of Statistics,',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/shephard.jpg?m=1629481859&itok=dHZz9R46'},
#    {'name': 'Pragya Sur',
#     'title': 'Assistant Professor of Statistics',
#     'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/sur_01_0.jpg?m=1629482118&itok=-Nx633Df'}]},
#  {'url': 'https://www.brown.edu/academics/public-health/biostats/people/faculty',
#   'res': [{'name': 'Alyssa Bilinski, Ph.D.',
#     'title': 'Peterson Family Assistant Professor of Health Policy, Assistant Professor of Health Services, Policy and Practice and Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/abilinsk_photo_.jpg'},
#    {'name': 'Stavroula  Chrysanthopoulou, Ph.D.',
#     'title': "Assistant Professor of Biostatistics, Director of the Master's Graduate Program in Biostatistics",
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/schrysan_photo_%20%281%29.jpg'},
#    {'name': 'Lorin  Crawford, Ph.D.',
#     'title': 'RGSS Assistant Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/lcrawfo1_photo_%20%281%29.jpg'},
#    {'name': 'Roberta De Vito, Ph.D.',
#     'title': 'Assistant Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/DeVito-400.jpg'},
#    {'name': 'Fenghai  Duan, Ph.D.',
#     'title': 'Associate Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Duan_2.jpg'},
#    {'name': 'Ani  Eloyan, Ph.D.',
#     'title': 'Assistant Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Eloyan1.jpg'},
#    {'name': 'Constantine  Gatsonis, Ph.D.',
#     'title': 'Henry Ledyard Goddard Professor of Biostatistics, Director of the Center for Statistical Sciences',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/GatsonisOffice.jpg'},
#    {'name': 'Roee  Gutman, Ph.D.',
#     'title': 'Associate Professor of Biostatistics, Director, Undergraduate Statistics Concentration',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Gutman_FacPic.jpg'},
#    {'name': 'Joseph  Hogan, Sc.D.',
#     'title': 'Carole and Lawrence Sirovich Professor of Public Health , Department Chair and Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Hogan_FacPic.jpg'},
#    {'name': 'Youjin  Lee, Ph.D.',
#     'title': 'Manning Assistant Professorship of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/YoujinLee.jpg'},
#    {'name': 'Tao  Liu, Ph.D.',
#     'title': 'Associate Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Liu100.jpg'},
#    {'name': 'Arman Oganisian, Ph.D.',
#     'title': 'Assistant Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/IMG_1677.jpeg'},
#    {'name': 'George  Papandonatos, Ph.D.',
#     'title': 'Professor of Biostatistics (R)',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Papandonatos_1.jpg'},
#    {'name': 'Alice Paul, Ph.D.',
#     'title': 'Assistant Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/PaulDSIPhoto.jpg'},
#    {'name': 'Christopher  Schmid, Ph.D.',
#     'title': 'Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/schmid-christopher-400.jpg'},
#    {'name': 'Jon  Steingrimsson, Ph.D.',
#     'title': 'Assistant Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Steingrimsson_Jon.jpg'},
#    {'name': 'Tom Trikalinos, Ph.D.',
#     'title': 'Professor of Health Services, Policy & Practice and Professor of Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Trikalinos.jpeg'},
#    {'name': 'Zhijin (Jean)  Wu, Ph.D.',
#     'title': 'Professor of Biostatistics, Director of the Doctoral Graduate Program in Biostatistics',
#     'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Z%20Wu100.jpg'}]},
#  {'url': 'https://stat.cornell.edu/people/faculty',
#   'res': [{'name': 'Alex Ayet',
#     'title': 'Visiting Scientist',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/ayet-alex-03.jpg?itok=RoJvS7_2'},
#    {'name': 'Sumanta Basu',
#     'title': 'Assistant Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/basu%20sumanta.jpg?itok=A8fvwHje'},
#    {'name': 'James Booth',
#     'title': 'Professor; Director of Graduate Studies',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Jim%20Booth_crop.jpg?itok=3hqwdDQ-'},
#    {'name': 'Florentina Bunea',
#     'title': 'Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Florentina%20BuneaCrop.jpg?itok=9U1cMeZb'},
#    {'name': 'Sreyoshi Das',
#     'title': 'Assistant Professor of the Practice',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Das%20Sreyoshi.jpg?itok=s1n8VH_y'},
#    {'name': 'Thomas DiCiccio',
#     'title': 'Associate Professor; Director of Undergraduate Studies',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/diciccio.jpg?itok=ZAWAzVe0'},
#    {'name': 'Ahmed El Alaoui',
#     'title': 'Assistant Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/El%20Alaoui%20Ahmed_0.jpg?itok=hopYkTeu'},
#    {'name': 'Jeremy Entner',
#     'title': 'Lecturer',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/entner%20jeremy%20edit.jpg?itok=42Y57gMz'},
#    {'name': 'Dominique Fourdrinier',
#     'title': 'Adjunct Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/fourdrinier.jpg?itok=3t71bemW'},
#    {'name': 'Christophe Giraud',
#     'title': 'Adjunct Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/christophe2.png?itok=bh4Q4La-'},
#    {'name': 'Joe Guinness',
#     'title': 'Associate Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/guiness.jpg?itok=sZ3aTlVb'},
#    {'name': 'Giles Hooker',
#     'title': 'Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Giles%20Hooker_crop.jpg?itok=_ns9SEBF'},
#    {'name': 'Elizabeth Karns',
#     'title': 'Senior Lecturer',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/karns.jpg?itok=TP88O20C'},
#    {'name': 'Kara Karpman',
#     'title': 'Adjunct Assistant Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Karpman%20Kara.jpg?itok=cySsJEz-'},
#    {'name': 'Kengo Kato',
#     'title': 'Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/kato%20kengo.jpg?itok=JDh9_Hq9'},
#    {'name': 'Nicholas Kiefer',
#     'title': 'Ta-Chung Liu Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Nicholas%20Kiefer_crop.jpg?itok=qVIs-_3g'},
#    {'name': 'Amy Kuceyeski',
#     'title': 'Adjunct Associate Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Amy_Kuceyeski.jpeg?itok=cJckdeGx'},
#    {'name': 'David S.  Matteson',
#     'title': 'Associate Department Chair; Associate Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/dave_matteson_crop.jpg?itok=-6ZYQz8g'},
#    {'name': 'Francesca Molinari',
#     'title': 'Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/francesca-molinari_crop.jpg?itok=7rxbabYa'},
#    {'name': 'Yang Ning',
#     'title': 'Assistant Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Yang-Ning-edit.jpg?itok=PuAOkZ3B'},
#    {'name': 'Michael Nussbaum',
#     'title': 'Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/michael-nussbaum_crop.jpg?itok=DWnvgI00'},
#    {'name': 'Kevin Packard',
#     'title': 'Visiting Lecturer',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Cornell%20Logo_0.jpg?itok=iv5-sYVv'},
#    {'name': 'David Ruppert',
#     'title': 'Andrew Schultz Jr. Professor of Engineering',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/Dave%20Ruppert_crop.jpg?itok=o86HBie6'},
#    {'name': 'Melissa Smith',
#     'title': 'Senior Lecturer',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/MelissaSmithCrop.jpg?itok=zHVVOUc7'},
#    {'name': 'Y. Samuel Wang',
#     'title': 'Assistant Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/wang%20y%20samuel.jpg?itok=TSUrORO6'},
#    {'name': 'Marten Wegkamp',
#     'title': 'Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/marten-wegkamp_crop.jpg?itok=eCzIOJVj'},
#    {'name': 'Martin Wells',
#     'title': 'Department Chair; Charles A. Alexander Professor of Statistical Sciences',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/marty-wells_crop.jpg?itok=rjWP9XlK'},
#    {'name': 'Dana Yang',
#     'title': 'Assistant Professor',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/yang%20dana.jpg?itok=z8HBa8Jd'},
#    {'name': 'Xiaolong Yang',
#     'title': 'Senior Lecturer and Director of the MPS Program',
#     'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/xiaolong-yang_crop.jpg?itok=ZF_W6atF'}]},
#  {'url': 'https://www.math.harvard.edu/people/',
#   'res': [{'name': 'Name / Email', 'title': 'Address / Contact', 'img': None},
#    {'name': 'Alpöge, Levent',
#     'title': 'Junior Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Levent_Alpoge.jpeg'},
#    {'name': 'Antunes, Jonier',
#     'title': 'Lecturer',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Jonier_Amaral_Antunes.jpeg'},
#    {'name': 'Armstrong, Maureen',
#     'title': 'Publications Coordinator (CMSA)',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/placeholder-image.jpg'},
#    {'name': 'Auroux, Denis',
#     'title': 'Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/auroux.jpg'},
#    {'name': 'Balibanu, Ana',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/balibanu-1.jpg'},
#    {'name': 'Ball, Andrew',
#     'title': 'Editorial Assistant',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/ball.jpg'},
#    {'name': 'Bamberg, Paul',
#     'title': 'Senior Lecturer',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/bamberg.jpg'},
#    {'name': 'Barkley, Grant',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Grant-Barkley.jpg'},
#    {'name': 'Bejleri, Dori',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/dori.jpg'},
#    {'name': 'Bell, Marjorie',
#     'title': 'Graduate Program Administrator',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/s_marjorie_bell.jpg'},
#    {'name': 'Betts, Alex',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Alexander_Betts.jpeg'},
#    {'name': 'Bogaevsky, Tatyana',
#     'title': 'Staff Assistant (CMSA)',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Tatyana-Bogaevsky.jpg'},
#    {'name': 'Bogdanova, Ekaterina',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Ekaterina_Bogdanova.jpeg'},
#    {'name': 'Bongers, Tyler',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Tyler-Bongers.jpg'},
#    {'name': 'Boretsky, Jonathan',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/jonathan-boretsky.jpg'},
#    {'name': 'Brentana, Pam',
#     'title': 'Administrative Coordinator',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/placeholder-image.jpg'},
#    {'name': 'Burcroff, Amanda',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Amanda_Burcroff.jpeg'},
#    {'name': 'Cain, Wes',
#     'title': 'Senior Lecturer',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/cain.jpg'},
#    {'name': 'Cavallo, Matthew',
#     'title': 'Lecturer',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Matt_Cavallo.jpeg'},
#    {'name': 'Chang, Jaewon',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/jaewon-chang.jpg'},
#    {'name': 'Chavez Sarmiento, Raul',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/chavez-sarmiento.jpg'},
#    {'name': 'Chen, Diana Lu',
#     'title': 'Financial Assosiate',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/chen-diana.jpg'},
#    {'name': 'Chen, Janet',
#     'title': 'Senior Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/chen-janet.jpg'},
#    {'name': 'Chen, Nathan',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Nathan_Chen.jpeg'},
#    {'name': 'Chen, Xujia',
#     'title': 'Junior Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Xujia_Chen.jpeg'},
#    {'name': 'Chua, Dexter',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/chua.jpg'},
#    {'name': 'Collins, Voula',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/collins2.jpg'},
#    {'name': 'Conner, Austin',
#     'title': 'Lecturer',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Austin_Conner.jpeg'},
#    {'name': 'Côté, Laurent',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Laurent-Cole.jpg'},
#    {'name': 'Cowan, Alexander',
#     'title': 'Post Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Alex-Cowan.jpg'},
#    {'name': 'Cuenca, Cesar',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/cuenca-ceaser.jpg'},
#    {'name': 'Dai, Xinle',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Clair-Dai.jpg'},
#    {'name': 'Defant, Colin',
#     'title': 'Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/placeholder-image.jpg'},
#    {'name': 'DeMarco, Laura',
#     'title': 'Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Laura-DeMarco.jpg'},
#    {'name': 'Devalapurkar, Sanath',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Sanath-Devalapurkar.jpg'},
#    {'name': 'Dong, Dingding',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Dingding-Dong.jpg'},
#    {'name': 'Dor, Yuval',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Yuval_Dor.jpeg'},
#    {'name': 'Dubova, Sofiia',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/dubova.jpg'},
#    {'name': 'Elkies, Noam',
#     'title': 'Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/elkies.jpg'},
#    {'name': 'Elmanto, Elden',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/elmanto.jpg'},
#    {'name': 'Eur, Christopher',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Christopher-Eur.jpg'},
#    {'name': 'Fernandes, Alaina',
#     'title': 'Administrator (CMSA)',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/AFernandes.jpeg'},
#    {'name': 'Freund, David',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/freund.jpg'},
#    {'name': 'Fu, Yuchen',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/fu.jpg'},
#    {'name': 'Gaer, Arthur',
#     'title': 'Systems Administrator',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/gaer.jpg'},
#    {'name': 'Gaetz, Christian',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Christian_Gaetz.jpeg'},
#    {'name': 'Gaitsgory, Dennis',
#     'title': 'Herchel Smith Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/gaitsgory.jpg'},
#    {'name': 'Gammage, Benjamin',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/gammage-b.jpg'},
#    {'name': 'Gao, Jiyang',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Johnny-Gao.jpg'},
#    {'name': 'Glazer, Elliot',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/glazer.jpg'},
#    {'name': 'Gorton, Sophia',
#     'title': 'Staff Assistant',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Sophia-Gorton.jpg'},
#    {'name': 'Gottlieb, Robin',
#     'title': 'Professor of the Practice in Teaching of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/gottlieb.jpg'},
#    {'name': 'Gross, Benedict',
#     'title': 'Professor Emeritus',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/gross.jpg'},
#    {'name': 'Grundmeier, Dusty',
#     'title': 'Associate Senior Lecturer',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/grundmeier.jpg'},
#    {'name': 'Guerra, Jill',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/guerra.jpg'},
#    {'name': 'Guigo i Corominas, Roderic',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Roderic_Guigo_Corominas.jpeg'},
#    {'name': 'Gundlach, Fabian',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/gundlach.jpg'},
#    {'name': 'Harris, Joe',
#     'title': 'Higgins Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/harris.jpg'},
#    {'name': 'Hironaka, Eriko',
#     'title': 'Associate',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/s_eriko.jpg'},
#    {'name': 'Hironaka, Heisuke',
#     'title': 'Professor Emeritus',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/hironaka.jpg'},
#    {'name': 'Hoek, Keeley',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Keeley-Hoek.jpg'},
#    {'name': 'Hopkins, Michael',
#     'title': 'George Putnam Professor of Pure and Applied Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/hopkins.jpg'},
#    {'name': 'Hu, Fei',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/FeiHu.jpeg'},
#    {'name': 'Jeffs, Maxim',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Maxim-Jeffs.jpg'},
#    {'name': 'Jiang, Yuhan',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Yuhan-Jiang.jpg'},
#    {'name': 'Jimenez, Cindy',
#     'title': 'Undergraduate Program Coordinator',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/jimenez.jpg'},
#    {'name': 'Kaufmann, Jenny',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/kaufmann.jpg'},
#    {'name': 'Kazhdan, David',
#     'title': 'Professor Emeritus',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/kazhdan.jpg'},
#    {'name': 'Kelly, Brendan',
#     'title': 'Senior Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/kelly.jpg'},
#    {'name': 'Kennedy, Larissa',
#     'title': 'Manager of Financial Operations',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/s_larissakennedy.jpg'},
#    {'name': 'Khromenkov, Yaroslav',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Khromenkov-Yaroslav.jpg'},
#    {'name': 'Kieffer, Jean',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Jean_Kieffer.jpeg'},
#    {'name': 'King, Jon',
#     'title': 'Financial Associate',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Jon-King.jpg'},
#    {'name': 'Kisin, Mark',
#     'title': 'Perkins Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/kisin.jpg'},
#    {'name': 'Knill, Oliver',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/knill.jpg'},
#    {'name': 'Kreslavskaya, Anna',
#     'title': 'Assistant Director of Research and Finance',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/kreslavskaya.jpg'},
#    {'name': 'Krieger, Holly',
#     'title': 'Associate',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/placeholder-image.jpg'},
#    {'name': 'Kronheimer, Peter',
#     'title': 'William Caspar Graustein Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/kronheimer.jpg'},
#    {'name': 'Kural, Michael',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Michael-Kural.jpg'},
#    {'name': 'Landesman, Aaron',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Aaron-Landesman.jpeg'},
#    {'name': 'Larson, Hannah',
#     'title': 'Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Hannah-Larson.jpg'},
#    {'name': 'Larson, Paul',
#     'title': 'Visiting Scholar',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Paul_Larson.jpeg'},
#    {'name': 'Lee, Si Ying',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/lee-si-yang.jpg'},
#    {'name': 'Lesourd, Martin',
#     'title': 'Lecturer/Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Martin_Lesourd.jpeg'},
#    {'name': 'Li-Huerta, Siyan',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/li.jpg'},
#    {'name': 'Li, Jiakai',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/jiakai.jpg'},
#    {'name': 'Lin, Alice',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Alice_Lin.jpeg'},
#    {'name': 'Lin, Kevin',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/placeholder-image.jpg'},
#    {'name': 'Liu, Yu Leon',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Yu_Leon_Liu.jpeg'},
#    {'name': 'Marks, Samuel',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/samuel.jpg'},
#    {'name': 'Martin, Adolfo Amadeus',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Adolfo_Amadeus_Martin.jpeg'},
#    {'name': 'Martin, Kimball',
#     'title': 'Associate',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Kimball-Martin.jpg'},
#    {'name': 'Maskin, Eric',
#     'title': 'Adams University Professor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/maskin.jpg'},
#    {'name': 'Mavraki, Niki Myrto',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Niki-Mavraki.jpg'},
#    {'name': 'Mazur, Barry',
#     'title': 'Gerhard Gade University Professor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/mazur-1.jpg'},
#    {'name': 'McMullen, Curtis',
#     'title': 'Maria Moors Cabot Professor of the Natural Sciences',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/mcmullenmsri1.jpg'},
#    {'name': 'Meng, Fanjun',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Fanjun-Meng.jpg'},
#    {'name': 'Menon, Reshma',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Reshma-Menon.jpg'},
#    {'name': 'Minder, Irene',
#     'title': 'Director of Administration and Finance',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/minder.jpg'},
#    {'name': 'Mondal, Puskar',
#     'title': 'Lecturer',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Puskar-Mondal.jpg'},
#    {'name': 'Moreland, Gwyneth',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/moreland.jpg'},
#    {'name': 'Mumford, David',
#     'title': 'Professor Emeritus',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/mumford.jpg'},
#    {'name': 'Nam, Taeuk',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Taeuk-Nam.jpg'},
#    {'name': 'Nathanson, Michael',
#     'title': 'Lecturers',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Michael_Nathanson.jpeg'},
#    {'name': 'Nie, Tian',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/nie.jpg'},
#    {'name': 'Nowak, Martin',
#     'title': 'Professor of Mathematics and Biology',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/nowak-1.jpg'},
#    {'name': 'Pajovic, Jelena',
#     'title': 'Staff Assistant',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Jelena-Pajovic.jpg'},
#    {'name': 'Park, Peter',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/park-peter.jpg'},
#    {'name': 'Park, Sung Gi',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/park-sung-gi.jpg'},
#    {'name': 'Petrov, Aleksandr',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/petrov.jpg'},
#    {'name': 'Poe, Milja',
#     'title': 'Associate',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Milja-Poe.jpg'},
#    {'name': 'Popa, Mihnea',
#     'title': 'Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Mihnea-Popa.jpg'},
#    {'name': 'Pstrągowski, Piotr',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Piotr-Pstragowski.jpg'},
#    {'name': 'Quintana, Dylan',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Dylan_Quintana.jpeg'},
#    {'name': 'Reeves, Wyatt',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Wyatt-Reeves.jpg'},
#    {'name': 'Rezchikov, Semon',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Semon_Rezchikov.jpeg'},
#    {'name': 'Saavedra, Rafael',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Rafael_Saavedra.jpeg'},
#    {'name': 'Schmid, Wilfried',
#     'title': 'Professor Emeritus',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/schmid.jpg'},
#    {'name': 'Seigal, Anna',
#     'title': 'Junior Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/anna_seigal.jpeg'},
#    {'name': 'Senger, Andrew',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/placeholder-image.jpg'},
#    {'name': 'Serrano López, Allechar',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/allechar_serrano.jpeg'},
#    {'name': 'Shah, Syed Waqar Ali',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/shah.jpg'},
#    {'name': 'Shani, Assaf',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/shani.jpg'},
#    {'name': 'Shen, Wanchun',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Rosie-Shen.jpg'},
#    {'name': 'Shusterman, Mark',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Mark-Shusterman.jpg'},
#    {'name': 'Siu, Yum-Tong',
#     'title': 'William Elwood Byerly Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/siu.jpg'},
#    {'name': 'Sternberg, Shlomo',
#     'title': 'Professor Emeritus',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/sternberg.jpg'},
#    {'name': 'Stewart, Natalie',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/placeholder-image.jpg'},
#    {'name': 'Sukarto, Eunice',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Eunice_Sukarto.jpeg'},
#    {'name': 'Sweeting, Naomi',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/naomi.jpg'},
#    {'name': 'Taubes, Cliff',
#     'title': 'William Petschek Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/taubes.jpg'},
#    {'name': 'Tayou, Salim',
#     'title': 'Benjamin Peirce Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Salim_Tayou.jpeg'},
#    {'name': 'Tkadlec, Pepa',
#     'title': 'Post-Doctoral Fellow',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Pepa-Tkadlec.jpeg'},
#    {'name': 'Torkaman, Tina',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Tina-Torkaman.jpeg'},
#    {'name': 'Vakil, Ravi',
#     'title': 'Visting Scholar',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Ravi_Vakil.jpeg'},
#    {'name': 'Vanterpool, Shirley',
#     'title': 'Financial Associate',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Shirley-Vanterpool.jpg'},
#    {'name': 'Vo, Duc',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/duc-vo.jpg'},
#    {'name': 'Walker, Hakim',
#     'title': 'Preceptor',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/walker.jpg'},
#    {'name': 'Wang, Charles',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/wang-charles.jpg'},
#    {'name': 'Wang, Joshua',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/wang-joshua.jpg'},
#    {'name': 'Wang, Weitong',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Weitong-Wang.jpg'},
#    {'name': 'Williams, Lauren',
#     'title': 'Dwight Parker Robinson Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/williams.jpg'},
#    {'name': 'Wilson, Dylan',
#     'title': 'Lecturer',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Dylan_Wilson.jpeg'},
#    {'name': 'Winsor, Karl',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/winsor.jpg'},
#    {'name': 'Wood, Melanie Matchett',
#     'title': 'Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Melanie-Matchett-Wood.jpg'},
#    {'name': 'Wood, Philip Matchett',
#     'title': 'Senior Lecturer, Research Scientist',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Philip-Matchett-Wood.jpg'},
#    {'name': 'Woodin, Hugh',
#     'title': 'Professor of Philosophy and of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/woodin.jpg'},
#    {'name': 'Xia, Jianqiao',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/jianqiao-xia.jpg'},
#    {'name': 'Xu, Kai',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/xu.jpg'},
#    {'name': 'Xu, Yujie',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Yujie_Xu.jpeg'},
#    {'name': 'Yang, David',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/yang-david.jpg'},
#    {'name': 'Yang, Lucy',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/yang-lucy.jpg'},
#    {'name': 'Yang, Yuxuan',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/yang-yuxuan.jpg'},
#    {'name': 'Yap, Jit Wu',
#     'title': 'Graduate Student',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Jit-Wu-Yap.jpg'},
#    {'name': 'Yau, Horng-Tzer',
#     'title': 'Merton Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/yau-horng-tzer.jpg'},
#    {'name': 'Yau, Shing-Tung',
#     'title': 'William Caspar Graustein Professor of Mathematics',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/yau-shing-tung.jpg'},
#    {'name': 'Yefremova, Anastasia',
#     'title': 'Publications Coordinator',
#     'img': 'https://www.math.harvard.edu/wp-content/uploads/Anastasia-Yefremova.jpg'}]}]

# %%
class_name_works = []
class_name_fails = []
for url in urls:
    try:
        res = get_department_info_class(url)
        item = {'url': url, 'res':res}
        class_name_works.append(item)
    except:
        class_name_fails.append(url)

# %%
len(class_name_works)
# Out:
# 32

# %%
tr_works = []
tr_fails = []

for url in urls:
    try:
        res = get_department_info_tr(url)
        item = {'url': url, 'res':res}
        tr_works.append(item)
    except:
        tr_fails.append(url)

# %%
tr_works

# %%
for i in class_name_works:
    print("________________________________________________________________________________________________________")
    print(f"url: {i.get('url')}")
    res = i.get('res')
    print(f"length: {len(res)}")
    print("___________")
    print(res[0])
    print(res[len(res)//2])
    print(res[-1])

# %%
# https://www.math.columbia.edu/people/faculty-by-rank/ 
# and https://math.yale.edu/people/all-faculty also doesn't work
class_name_fails.append("https://www.math.columbia.edu/people/faculty-by-rank/")
class_name_fails.append("https://math.yale.edu/people/all-faculty")

# %% [markdown]
# ## Using siblings

# %%
# similar to class name in using recursion, but get all the profiles using siblings instead
def find_profile_siblings(tags):
    parents = []
    for tag in tags:
        parents.append(tag.parent)
    if len(set(parents)) == 1:
        tag = tags[1]
        tag_lst = []
        p_siblings = tag.previous_siblings
        n_siblings = tag.next_siblings
        tag_lst.extend(list(p_siblings))
        tag_lst.append(tag)
        tag_lst.extend(list(n_siblings))
        return tag, tag_lst
    else:
        return find_profile_siblings(parents)

# %%
def get_department_info_siblings(URL):
    # get the soup (entire webpage)
    soup = get_soup(URL)
    
    # get 3 headshot tags in different pos. Because all the pages have headshots ('img' in html), 
    # that's something in common for all pages regardless of the design 
    headshots = select_headshots(soup)
    
    tmp_tag, profs = find_profile_siblings(headshots)
    src_or_not = src_or_srcset(headshots[1])
        
    # find the position of name and title in the tmp_tag (from 1 of parents of headshots)
    name_pos = find_name_pos(tmp_tag)
    title_pos = find_title_pos(tmp_tag)

    items = []
    # get info for each profile
    for p in profs:
        name = find_by_pos(p, name_pos)
        title = find_by_pos(p, title_pos)
        img = find_img(p, src_or_not)
        item = {'name': name, 'title': title, 'img':img}
        items.append(item)
    return items

# %%
urls = ["https://stat.columbia.edu/department-directory/faculty-and-lecturers/", 
         "https://statistics.wharton.upenn.edu/faculty/faculty-list/",
         "https://statistics.fas.harvard.edu/faculty",
         "https://statistics.yale.edu/people",
         "https://www.brown.edu/academics/public-health/biostats/people/faculty",
         "https://stat.cornell.edu/people/faculty",
         "https://www.math.columbia.edu/people/faculty-by-rank/",
         "https://www.math.upenn.edu/people/standing-faculty",
         "https://www.math.harvard.edu/people/",
         "https://math.yale.edu/people/all-faculty",
         "https://www.brown.edu/academics/math/faculty", 
         "https://math.dartmouth.edu/people/people-select.php?list=permanent",
         "https://economics.dartmouth.edu/people",
         "https://economics.yale.edu/people/faculty",
         "https://english.columbia.edu/content/faculty#!#%2Fviews-display-37",
         "http://ealac.columbia.edu/people/professors/",
         "https://english.yale.edu/people/ladder-faculty",
         "https://www.ieor.columbia.edu/directory?gsarqfields%5Bbiotypetid%5D=30",
         "https://www.cs.columbia.edu/people/faculty/",
         "https://afamstudies.columbia.edu/content/people",
         "https://anthropology.columbia.edu/content/faculty-directory",
         "https://www.biochem.cuimc.columbia.edu/research/research-faculty",
         "https://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations/people/faculty",
         "https://arts.columbia.edu/film/",
         "https://arth.sas.upenn.edu/people/standing-faculty",
         "https://www.english.upenn.edu/people/faculty",
         "https://www.ling.upenn.edu/people/faculty",
         "https://hss.sas.upenn.edu/people",
         "https://english.dartmouth.edu/people",
         "https://german.dartmouth.edu/people",
         "https://ascl.dartmouth.edu/people",
         "https://chemistry.dartmouth.edu/people",
         "https://web.cs.dartmouth.edu/people",
         "https://ealc.fas.harvard.edu/people/taxonomy/term/6536",
         "https://english.fas.harvard.edu/our-people",
         "https://philosophy.fas.harvard.edu/faculty-1",
         "https://cals.cornell.edu/global-development/about/people/faculty",
         "https://cals.cornell.edu/landscape-architecture/people",
         "https://aap.cornell.edu/academics/faculty",
         "https://anthropology.cornell.edu/anthropology-faculty"
        ]
