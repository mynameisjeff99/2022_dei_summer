# %%
import requests 
from bs4 import BeautifulSoup 
import re
from statistics import mode
import unidecode

# %% [markdown]
# # Helper functions

# %%
def get_soup(URL):
    r = requests.get(URL) 
    soup = BeautifulSoup(r.content, 'html5lib')
    return soup.body

# %%
def select_headshots(soup):
    headshots = soup.find_all('img')
    if len(headshots) < 3:
        raise Exception("Not enough imgs")
    elif len(headshots) < 10:
        items = [headshots[len(headshots)//3], headshots[len(headshots)//3*2], headshots[len(headshots)-2]]
    elif len(headshots) > 50:
        items = [headshots[len(headshots)//10*i] for i in range(1,10)]
    else:
        items = [headshots[len(headshots)//7*i] for i in range(1,7)]
    return items

# %%
def find_name_pos(tag):
    pos = 0
    strs = tag.stripped_strings
    while True:
        try:
            s = next(strs)
            if re.match("^([a-zA-Z.-]*[,]* [a-zA-Z.]* [a-zA-Z.-]*|[a-zA-Z.-]*[,]* [a-zA-Z.-]*)(, Ph.D.)*$",
                      unidecode.unidecode(" ".join(s.split()))):
                if "University" not in s and "College" not in s and "Department" not in s\
                and "Faculty" not in s and "Research" not in s and "Interest" not in s and "Staff" not in s\
                and "Profile" not in s and "Student" not in s:
                    return pos
            pos += 1
        except:
            raise Exception("name position not found")

# %%
re.match("^(, Ph.D.)*$", ", Ph.D.")
# Out:
# <re.Match object; span=(0, 7), match=', Ph.D.'>

# %%
def find_title_pos(tag):
    pos = 0
    strs = tag.stripped_strings
    while True:
        try:
            s = next(strs)
            if re.match("(?i).*(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|PhD).*", s):
                return pos
            else:
                pos += 1
        except:
            raise Exception("title position not found")

# %%
def find_pos(tags):
    name_positions = []
    title_positions = []
    for tag in tags:
        try:
            name_pos = find_name_pos(tag)
            title_pos = find_title_pos(tag)
            name_positions.append(name_pos)
            title_positions.append(title_pos)
        except:
            pass
        
    if len(name_positions) == 0:
        raise Exception("failed to find positions")
    name_pos = mode(name_positions)
    title_pos = mode(title_positions)
    return name_pos, title_pos

# %%
def is_name(s):
    if s is None:
        return None
    elif re.match("^([a-zA-Z.-]*[,]* [a-zA-Z.]* [a-zA-Z.-]*|[a-zA-Z.-]*[,]* [a-zA-Z.-]*)(, Ph.D.)*$",
                  unidecode.unidecode(" ".join(s.split()))):
        return s
    else:
        return None

# %%
def is_title(s):
    if s is None:
        return None
    elif re.match("(?i).*(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Doctoral|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|Dean|Senior|Preceptor).*", s):
        return s
    else:
        return None

# %%
def find_by_pos(tag, pos):
    it = tag.stripped_strings
    try:
        item = next(x for i,x in enumerate(it) if i==pos)
    except:
        item = None
    return item

# %%
def find_img(tag):    
    img_tag = tag.find('img')
    if img_tag is not None:
        try:
            return img_tag['src']
        except:
            pass

        try:
            return img_tag['srcset'].split()[0]
        except:
            pass
    return None

# %%
def get_info(profs, name_pos, title_pos):
    items = []
    total = 0
    no_fails = 0
    for p in profs:
        name = find_by_pos(p, name_pos)
        name = is_name(name)
        title = find_by_pos(p, title_pos)
        title = is_title(title)
        img = find_img(p)
        if name is not None and title is not None:
            item = {'name': name, 'title': title, 'img':img}
            items.append(item)
            total += 1
            if name is None or title is None:
                no_fails += 1
    if no_fails/total > 1/3 or total < 5:
        raise Exception("FAILED")
    return items

# %% [markdown]
# # Different methods

# %% [markdown]
# ## tr

# %%
def find_profs_tr(soup):
    profs = soup.find_all('tr')
    
    if len(profs) == 0:
        raise Exception("No tr")
    return profs

# %%
def get_department_info_tr(soup):
    profs = find_profs_tr(soup)
    
    tags = [profs[len(profs)//5*i] for i in range(1,6)]

    name_pos, title_pos = find_pos(tags)
        
    items = get_info(profs, name_pos, title_pos)
    return items

# %%
#get_department_info_tr(get_soup("https://statistics.yale.edu/people"))

# %% [markdown]
# ## Profile class name

# %%
def find_profile_class(tag, levels_allowed):
    if levels_allowed == 0:
        raise Exception("Class name not found")
    s = ' '.join(list(tag.stripped_strings))
    if re.search(r"(?i)(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|PhD|Dean|Senior|Preceptor)", s):
        tag_s = str(tag)
        m = re.findall(r'class="(.+?)"', tag_s)
        # allow going up 2 more levels if 'class=' is not found 
        if len(m) == 0:
            return find_profile_class(tag.parent, levels_allowed - 1)
        else:
            return tag, m[0]
    else:
        return find_profile_class(tag.parent, levels_allowed)

# %%
def get_department_info_class(soup):
    headshots = select_headshots(soup)

    profile_classes = []
    tags = []
    for headshot in headshots:
        try:
            tag, profile_c = find_profile_class(headshot, 2)
            profile_classes.append(profile_c)
            tags.append(tag)
        except:
            pass
        
    if len(profile_classes) == 0:
        raise Exception("class name not found")
    elif len(set(profile_classes)) == len(profile_classes):
        raise Exception("class names for profiles are different")
    else:
        profile_class = mode(profile_classes)
    
    tags = [t for (t, c) in zip(tags, profile_classes) if c == profile_class]
    
    name_pos, title_pos = find_pos(tags)

    profs = soup.find_all(attrs = {'class':profile_class})
    items = get_info(profs, name_pos, title_pos)
    return items

# %%
#get_department_info_class(get_soup("https://stat.columbia.edu/department-directory/faculty-and-lecturers/"))

# %% [markdown]
# ## Children

# %%
def find_profile_children(tags):
    parents = []
    parent = None
    while parent is None:
        new_tags = []
        for tag in tags:
            tmp_parent = tag.parent
            if tmp_parent in parents:
                target_tag = tag
                parent = tmp_parent
                break
            else:
                parents.append(tmp_parent)
                new_tags.append(tmp_parent)
        tags = new_tags
            
    tag_name = target_tag.name
    children = parent.findChildren(recursive=False)
    items = []
    for c in children:
        if c.name == tag_name:
            items.append(c)
    return items

# %%
def get_department_info_children(soup):
    headshots = select_headshots(soup)
        
    profs = find_profile_children(headshots)
    
    tags = []
    for h in headshots:
        for p in profs:
            if str(h) in str(p):
                tags.append(p)
                break
    tags = list(set(tags))
    if len(tags) / len(headshots) < 2/3:
        raise Exception("children failed")
    
    name_pos, title_pos = find_pos(tags)

    items = get_info(profs, name_pos, title_pos)
    return items

# %%
#get_department_info_children(get_soup("https://statistics.fas.harvard.edu/faculty/"))

# %% [markdown]
# ## Brute Forcing

# %%
def find_profile_bf(tag, count):
    s = ' '.join(list(tag.stripped_strings))
    if re.search(r"(?i)(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|PhD|Dean|Senior|Preceptor)", s):
        return tag, count
    else:
        count = count + 1
        return find_profile_bf(tag.parent, count)

# %%
def get_department_info_bf(soup):
    headshots = select_headshots(soup)
    
    counts = []
    tags = []
    for headshot in headshots:
        try:
            tag, count = find_profile_bf(headshot, 0)
            counts.append(count)
            tags.append(tag)
        except:
            pass
    
    
    if len(counts) == 0:
        raise Exception("bf failed")
    elif len(set(counts)) == len(counts):
        raise Exception("counts are all different")
    else:
        count = mode(counts)
    
    tags = [t for (t, c) in zip(tags, counts) if c == count]
    name_pos, title_pos = find_pos(tags)
    
    all_headshots = soup.find_all('img')
    profs = []
    for t in all_headshots:
        for i in range(count):
            t = t.parent
        profs.append(t)
    items = get_info(profs, name_pos, title_pos)
    return items

# %%
#get_department_info_bf(get_soup("https://cals.cornell.edu/global-development/about/people/faculty"))

# %% [markdown]
# # Putting everything together

# %%
def get_department_info(URL):
    soup = get_soup(URL)
    res_lst = []
    print("______________________")
    print(URL)
    try:
        res_lst.append(["tr", get_department_info_tr(soup)])
    except:
        pass
    
    try:
        res_lst.append(["children", get_department_info_children(soup)])
    except:
        pass
    
    try:
        res_lst.append(["class", get_department_info_class(soup)])
    except:
        pass
    
    if len(res_lst) == 0:
        try:
            return(['bf', get_department_info_bf(soup)])
        except:
            print("FAILED")
            raise Exception("FAILED")
    else:
        curr = None
        for res in res_lst:
            if curr is None or len(res[1]) > len(curr[1]):
                curr = res
        return curr

# %% [markdown]
# # Testing

# %%
url = "http://classics.columbia.edu/profiles"
#print(select_headshots(get_soup(url))[0])
tmp = select_headshots(get_soup(url))[0]
find_profile_class(tmp, 2)
#get_department_info_class(get_soup(url))
#get_department_info_children(get_soup(url))
#get_department_info("http://classics.columbia.edu/profiles")
# Out:
# (<div class="summary-item-list sqs-gallery">
#
#          <div class="summary-item summary-item-record-type-image sqs-gallery-design-autogrid-slide summary-item-has-thumbnail summary-item-has-excerpt summary-item-has-cats summary-item-has-tags summary-item-has-author" data-click-through-url="/dimitris-antoniou">
#
#
#
#
#
#      <div class="summary-thumbnail-outer-container">
#        <a class="summary-thumbnail-container sqs-gallery-image-container js-gallery-lightbox-opener" data-description='&lt;p class="" style="white-space:pre-wrap;"&gt;(212)-853-8241&lt;br&gt;da2500@columbia.edu&lt;br&gt;503 Fayerweather Hall&lt;br&gt;History and anthropology of Modern Greece; Ottoman history; Dictatorial legacies; Architecture and public space&lt;/p&gt;' data-title="Dimitris Antoniou" href="/dimitris-antoniou">
#          <div class="summary-thumbnail img-wrapper" data-animation-role="image">
#
#
#
#
#      <!-- Main Image -->
#      <img alt="Dimitris Antoniou" class="summary-thumbnail-image" data-image="https://images.squarespace-cdn.com/content/v1/5581c452e4b0f32e90fc9a64/1487006147926-2IAQ84SXFO9V1859A942/%CE%91%CE%BD%CF%84%CF%89%CE%BD%CE%B9%CC%81%CE%BF%CF%85.%CE%A6%CF%89%CF%84..jpg" data-image-dimensions="2027x2606" data-image-focal-point="0.5,0.5" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5581c452e4b0f32e90fc9a64/1487006147926-2IAQ84SXFO9V1859A942/%CE%91%CE%BD%CF%84%CF%89%CE%BD%CE%B9%CC%81%CE%BF%CF%85.%CE%A6%CF%89%CF%84..jpg"/>
#
#
#
#
#
#
#
#
#
#      </div>
#    </a>
#
#      <!-- Products: Quick View -->
#
#
#      </div>
#
#
#
#
#
#            <div class="summary-content sqs-gallery-meta-container" data-animation-role="content">
#
#
#              <div class="summary-metadata-container summary-metadata-container--above-title">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#
#
#                <div class="summary-title">
#                  <a class="summary-title-link" href="/dimitris-antoniou">Dimitris Antoniou</a></div>
#
#
#
#              <div class="summary-metadata-container summary-metadata-container--below-title">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#
#
#
#
#
#
#
#
#                  <div class="summary-excerpt summary-excerpt-gallery-caption-description"><p class="" style="white-space:pre-wrap;">(212)-853-8241<br/>da2500@columbia.edu<br/>503 Fayerweather Hall<br/>History and anthropology of Modern Greece; Ottoman history; Dictatorial legacies; Architecture and public space</p></div>
#
#
#
#
#
#
#              <div class="summary-metadata-container summary-metadata-container--below-content">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#            </div>
#          </div>
#
#          <div class="summary-item summary-item-record-type-image sqs-gallery-design-autogrid-slide summary-item-has-thumbnail summary-item-has-excerpt summary-item-has-cats summary-item-has-tags summary-item-has-author summary-item-has-comments-enabled" data-click-through-url="/kathy-hannah-eden">
#
#
#
#
#
#      <div class="summary-thumbnail-outer-container">
#        <a class="summary-thumbnail-container sqs-gallery-image-container js-gallery-lightbox-opener" data-description="&lt;p&gt;(212) 854

#
#
#
#
#
#      <div class="summary-thumbnail-outer-container">
#        <a class="summary-thumbnail-container sqs-gallery-image-container js-gallery-lightbox-opener" data-description="&lt;p&gt;(212) 854-5683&lt;br&gt;kv2018@columbia.edu&lt;br&gt;614 Hamilton Hall&lt;br&gt;Latin literature of the late Republican and early Imperial periods; Roman philosophy, esp. Cicero; intellectual history&lt;br&gt;(Photograph by Isaia Crosson)&lt;/p&gt;" data-title="Katharina Volk" href="/katharina-volk">
#          <div class="summary-thumbnail img-wrapper" data-animation-role="image">
#
#
#
#
#      <!-- Main Image -->
#      <img alt="Katharina Volk" class="summary-thumbnail-image" data-image="https://images.squarespace-cdn.com/content/v1/5581c452e4b0f32e90fc9a64/1445738625802-3UQQ7OTDWOMJEU67ACJ2/placeholder_2.png" data-image-dimensions="5616x3744" data-image-focal-point="0.5333333333333333,0.4111111111111111" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5581c452e4b0f32e90fc9a64/1445738625802-3UQQ7OTDWOMJEU67ACJ2/placeholder_2.png"/>
#
#
#
#
#
#
#
#
#
#      </div>
#    </a>
#
#      <!-- Products: Quick View -->
#
#
#      </div>
#
#
#
#
#
#            <div class="summary-content sqs-gallery-meta-container" data-animation-role="content">
#
#
#              <div class="summary-metadata-container summary-metadata-container--above-title">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#
#
#                <div class="summary-title">
#                  <a class="summary-title-link" href="/katharina-volk">Katharina Volk</a></div>
#
#
#
#              <div class="summary-metadata-container summary-metadata-container--below-title">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#
#
#
#
#
#
#
#
#                  <div class="summary-excerpt summary-excerpt-gallery-caption-description"><p>(212) 854-5683<br/>kv2018@columbia.edu<br/>614 Hamilton Hall<br/>Latin literature of the late Republican and early Imperial periods; Roman philosophy, esp. Cicero; intellectual history<br/>(Photograph by Isaia Crosson)</p></div>
#
#
#
#
#
#
#              <div class="summary-metadata-container summary-metadata-container--below-content">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#            </div>
#          </div>
#
#          <div class="summary-item summary-item-record-type-image sqs-gallery-design-autogrid-slide summary-item-has-thumbnail summary-item-has-excerpt summary-item-has-cats summary-item-has-tags summary-item-has-author summary-item-has-comments-enabled" data-click-through-url="/gareth-williams">
#
#
#
#
#
#      <div class="summary-thumbnail-outer-container">
#        <a class="summary-thumbnail-container sqs-gallery-image-container js-gallery-lightbox-opener" data-description="&lt;p&gt;(212) 854-2850&lt;br /&gt;gdw5@columbia.edu&lt;br /&gt;615 Hamilton Hall&lt;br /&gt;Classical Latin poetry, especially elegy; Silver Latin poetry; Senecan prose&lt;br /&gt;(Photograph by Isaia Crosson)&lt;/p&gt;" data-title="Gareth Williams" href="/gareth-williams">
#          <div class="summary-thumbnail img-wrapper" data-animation-role="image">
#
#
#
#
#      <!-- Main Image -->
#      <img alt="Gareth Williams" class="summary-thumbnail-image" data-image="https://images.squarespace-cdn.com/content/v1/5581c452e4b0f32e90fc9a64/1524491837829-KDUVG2K3KE8S8NCS0KMR/Gareth+Williams.jpg" data-image-dimensions="2500x1667" data-image-focal-point="0.5,0.5" data-load="false" data-src="https://images.squarespace-cdn.com/content/v1/5581c452e4b0f32e90fc9a64/1524491837829-KDUVG2K3KE8S8NCS0KMR/Gareth+Williams.jpg"/>
#
#
#
#
#
#
#
#
#
#      </div>
#    </a>
#
#      <!-- Products: Quick View -->
#
#
#      </div>
#
#
#
#
#
#            <div class="summary-content sqs-gallery-meta-container" data-animation-role="content">
#
#
#              <div class="summary-metadata-container summary-metadata-container--above-title">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#
#
#                <div class="summary-title">
#                  <a class="summary-title-link" href="/gareth-williams">Gareth Williams</a></div>
#
#
#
#              <div class="summary-metadata-container summary-metadata-container--below-title">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#
#
#
#
#
#
#
#
#                  <div class="summary-excerpt summary-excerpt-gallery-caption-description"><p>(212) 854-2850<br/>gdw5@columbia.edu<br/>615 Hamilton Hall<br/>Classical Latin poetry, especially elegy; Silver Latin poetry; Senecan prose<br/>(Photograph by Isaia Crosson)</p></div>
#
#
#
#
#
#
#              <div class="summary-metadata-container summary-metadata-container--below-content">
#
#                <div class="summary-metadata summary-metadata--primary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#
#                <div class="summary-metadata summary-metadata--secondary">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  </div>
#              </div>
#
#            </div>
#          </div>
#
#      </div>,
#  'summary-item-list sqs-gallery')

# %%
urls = ["https://stat.columbia.edu/department-directory/faculty-and-lecturers/", 
         "https://statistics.wharton.upenn.edu/faculty/faculty-list/",
         "https://statistics.fas.harvard.edu/faculty",
         "https://statistics.yale.edu/people",
         "https://www.brown.edu/academics/public-health/biostats/people/faculty",
         "https://stat.cornell.edu/people/faculty",
         "https://www.math.columbia.edu/people/faculty-by-rank/",
         "https://www.math.upenn.edu/people/standing-faculty",
         "https://www.math.harvard.edu/people/",
         "https://math.yale.edu/people/all-faculty",
         "https://www.brown.edu/academics/math/faculty", 
         "https://math.dartmouth.edu/people/people-select.php?list=permanent",
         "https://economics.dartmouth.edu/people",
         "https://economics.yale.edu/people/faculty",
         "https://english.columbia.edu/content/faculty#!#%2Fviews-display-37",
         "http://ealac.columbia.edu/people/professors/",
         "https://english.yale.edu/people/ladder-faculty",
         "https://www.ieor.columbia.edu/directory?gsarqfields%5Bbiotypetid%5D=30",
         "https://www.cs.columbia.edu/people/faculty/",
         "https://afamstudies.columbia.edu/content/people",
         "https://anthropology.columbia.edu/content/faculty-directory", # headshots are not img
         "https://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations/people/faculty",
         "https://arts.columbia.edu/faculty",
         "https://arth.sas.upenn.edu/people/standing-faculty",
         "https://www.english.upenn.edu/people/faculty",
         "https://www.ling.upenn.edu/people/faculty",
         "https://hss.sas.upenn.edu/people",
         "https://english.dartmouth.edu/people",
         "https://german.dartmouth.edu/people",
         "https://ascl.dartmouth.edu/people",
         "https://chemistry.dartmouth.edu/people",
         "https://web.cs.dartmouth.edu/people",
         "https://ealc.fas.harvard.edu/people/taxonomy/term/6536",
         "https://english.fas.harvard.edu/our-people",
         "https://philosophy.fas.harvard.edu/faculty-1",
         "https://cals.cornell.edu/global-development/about/people/faculty",
         "https://cals.cornell.edu/landscape-architecture/people",
         "https://aap.cornell.edu/academics/faculty",
         "https://anthropology.cornell.edu/anthropology-faculty"
        ]

# %%
works = []
fails = []
for url in urls:
    try:
        method, res = get_department_info(url)
        item = {'url': url, 'method': method, 'res':res}
        works.append(item)
    except:
        fails.append(url)
# Out:
# ______________________
# https://stat.columbia.edu/department-directory/faculty-and-lecturers/
# ______________________
# https://statistics.wharton.upenn.edu/faculty/faculty-list/
# ______________________
# https://statistics.fas.harvard.edu/faculty
# ______________________
# https://statistics.yale.edu/people
# ______________________
# https://www.brown.edu/academics/public-health/biostats/people/faculty
# ______________________
# https://stat.cornell.edu/people/faculty
# ______________________
# https://www.math.columbia.edu/people/faculty-by-rank/
# ______________________
# https://www.math.upenn.edu/people/standing-faculty
# ______________________
# https://www.math.harvard.edu/people/
# ______________________
# https://math.yale.edu/people/all-faculty
# ______________________
# https://www.brown.edu/academics/math/faculty
# ______________________
# https://math.dartmouth.edu/people/people-select.php?list=permanent
# ______________________
# https://economics.dartmouth.edu/people
# ______________________
# https://economics.yale.edu/people/faculty
# ______________________
# https://english.columbia.edu/content/faculty#!#%2Fviews-display-37
# ______________________
# http://ealac.columbia.edu/people/professors/
# ______________________
# https://english.yale.edu/people/ladder-faculty
# ______________________
# https://www.ieor.columbia.edu/directory?gsarqfields%5Bbiotypetid%5D=30
# ______________________
# https://www.cs.columbia.edu/people/faculty/
# ______________________
# https://afamstudies.columbia.edu/content/people
# ______________________
# https://anthropology.columbia.edu/content/faculty-directory
# FAILED
# ______________________
# https://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations/people/faculty
# ______________________
# https://arts.columbia.edu/faculty
# FAILED
# ______________________
# https://arth.sas.upenn.edu/people/standing-faculty
# ______________________
# https://www.english.upenn.edu/people/faculty
# ______________________
# https://www.ling.upenn.edu/people/faculty
# ______________________
# https://hss.sas.upenn.edu/people
# ______________________
# https://english.dartmouth.edu/people
# ______________________
# https://german.dartmouth.edu/people
# ______________________
# https://ascl.dartmouth.edu/people
# ______________________
# https://chemistry.dartmouth.edu/people
# ______________________
# https://web.cs.dartmouth.edu/people
# ______________________
# https://ealc.fas.harvard.edu/people/taxonomy/term/6536
# ______________________
# https://english.fas.harvard.edu/our-people
# ______________________
# https://philosophy.fas.harvard.edu/faculty-1
# ______________________
# https://cals.cornell.edu/global-development/about/people/faculty
# ______________________
# https://cals.cornell.edu/landscape-architecture/people
# ______________________
# https://aap.cornell.edu/academics/faculty
# ______________________
# https://anthropology.cornell.edu/anthropology-faculty

# %%
for i in works:
    print("________________________________________________________________________________________________________")
    print(f"url: {i.get('url')}")
    res = i.get('res')
    method = i.get('method')
    print(f"method: {method}")
    print(f"length: {len(res)}")
    print("___________")
    print(res[0])
    print(res[len(res)//2])
    print(res[-1])
# Out:
# ________________________________________________________________________________________________________
# url: https://stat.columbia.edu/department-directory/faculty-and-lecturers/
# method: class
# length: 59
# ___________
# {'name': 'David Blei', 'title': 'Professor', 'img': 'https://stat.columbia.edu/wp-content/uploads/connections-images/david-blei/Blei-David-1.jpg'}
# {'name': 'Banu Baydil', 'title': 'Lecturer in Discipline, Co-Director of M.A. Programs', 'img': 'https://stat.columbia.edu/wp-content/uploads/connections-images/banu-baydil/banu_original.jpg'}
# {'name': 'Rongning Wu', 'title': 'Adjunct Assistant Professor', 'img': None}
# ________________________________________________________________________________________________________
# url: https://statistics.wharton.upenn.edu/faculty/faculty-list/
# method: class
# length: 51
# ___________
# {'name': 'Bhaswar B. Bhattacharya', 'title': 'Assistant Professor of Statistics and Data Science', 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2016/09/Bhaswar_Homepage_Cropped.jpg'}
# {'name': 'Mingyao Li', 'title': 'Professor of Biostatistics, Professor of Statistics and Data Science', 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2016/11/MingyaoLi.jpg'}
# {'name': 'Larry A. Shepp', 'title': 'Professor of Statistics', 'img': 'https://faculty.wharton.upenn.edu/wp-content/uploads/2012/04/Larryshepp.JPG'}
# ________________________________________________________________________________________________________
# url: https://statistics.fas.harvard.edu/faculty
# method: class
# length: 27
# ___________
# {'name': 'Morgane Austern', 'title': 'Assistant Professor', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/img-20210401-wa0022.jpg?m=1647356154&itok=X-5OHRTO'}
# {'name': 'Kevin Rader', 'title': 'Senior Preceptor in Statistics,', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/rader.jpg?m=1630613609&itok=y38IEcAG'}
# {'name': 'Julie Vu', 'title': 'Preceptor in Statistics', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/statistics-2/files/vu_resize.jpg?m=1564665801&itok=SEwpSYEK'}
# ________________________________________________________________________________________________________
# url: https://statistics.yale.edu/people
# method: tr
# length: 107
# ___________
# {'name': 'Andrew Barron', 'title': 'Charles C. and Dorothea S. Dilley Professor of Statistics & Data Science', 'img': 'https://statistics.yale.edu/sites/default/files/styles/people_user_image/public/pictures/picture-15-1362597227.jpg?itok=sPNt5_6y'}
# {'name': 'Xinyang Hu', 'title': 'Graduate School Student', 'img': 'https://statistics.yale.edu/sites/default/files/styles/people_user_image/public/pictures/picture-1911-1625241361.jpg?itok=HQxtP3I7'}
# {'name': 'Elizavette Torres', 'title': 'Event Coordinator and Faculty Support', 'img': 'https://statistics.yale.edu/sites/default/files/styles/people_user_image/public/pictures/picture-56-1506962214.jpg?itok=_yx2L5Re'}
# ________________________________________________________________________________________________________
# url: https://www.brown.edu/academics/public-health/biostats/people/faculty
# method: children
# length: 16
# ___________
# {'name': 'Alyssa Bilinski, Ph.D.', 'title': 'Peterson Family Assistant Professor of Health Policy, Assistant Professor of Health Services, Policy and Practice and Biostatistics', 'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/abilinsk_photo_.jpg'}
# {'name': 'Youjin  Lee, Ph.D.', 'title': 'Manning Assistant Professorship of Biostatistics', 'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/YoujinLee.jpg'}
# {'name': 'Tom Trikalinos, Ph.D.', 'title': 'Professor of Health Services, Policy & Practice and Professor of Biostatistics', 'img': 'https://www.brown.edu/academics/public-health/biostats/sites/biostats/files/images/people/Trikalinos.jpeg'}
# ________________________________________________________________________________________________________
# url: https://stat.cornell.edu/people/faculty
# method: children
# length: 29
# ___________
# {'name': 'Alex Ayet', 'title': 'Visiting Scientist', 'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/ayet-alex-03.jpg?itok=RoJvS7_2'}
# {'name': 'Kengo Kato', 'title': 'Professor', 'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/kato%20kengo.jpg?itok=JDh9_Hq9'}
# {'name': 'Dana Yang', 'title': 'Assistant Professor', 'img': 'https://stat.cornell.edu/sites/default/files/styles/square_portrait/public/yang%20dana.jpg?itok=z8HBa8Jd'}
# ________________________________________________________________________________________________________
# url: https://www.math.columbia.edu/people/faculty-by-rank/
# method: class
# length: 66
# ___________
# {'name': 'New York', 'title': 'Professor', 'img': '//www.math.columbia.edu/department/website/wp-content/uploads/connections-images/mohammed-abouzaid/abouzaid_original-4f5f03379ff345dc53d8afd47027fbab.jpg'}
# {'name': 'New York', 'title': 'Professor Emeritus', 'img': '//www.math.columbia.edu/department/website/wp-content/uploads/connections-images/walter-neumann/neumann_original-1e4b314bf688c7bf3eeafd5c4b4a8f7f.jpg'}
# {'name': 'New York', 'title': 'Adjunct Assistant Professor', 'img': '//www.math.columbia.edu/department/website/wp-content/uploads/connections-images/elliott-stein/stein_original-8b3dc83222e11b6f5ae245daafbc87cd.jpg'}
# ________________________________________________________________________________________________________
# url: https://www.math.upenn.edu/people/standing-faculty
# method: class
# length: 32
# ___________
# {'name': 'Jonathan  Block', 'title': 'Professor of Mathematics', 'img': 'https://www.math.upenn.edu/sites/default/files/styles/profile-thumb/public/Block_0.jpg?itok=8lsKofiB'}
# {'name': 'Davi  Maximo', 'title': 'Assistant Professor of Mathematics', 'img': '../sites/www.math.upenn.edu/themes/math/images/penn-shield.png'}
# {'name': 'Wolfgang  Ziller', 'title': 'Professor of Mathematics Emeritus', 'img': 'https://www.math.upenn.edu/sites/default/files/styles/profile-thumb/public/Ziller.jpg?itok=jZJNBmUo'}
# ________________________________________________________________________________________________________
# url: https://www.math.harvard.edu/people/
# method: children
# length: 147
# ___________
# {'name': 'Alpöge, Levent', 'title': 'Junior Fellow', 'img': 'https://www.math.harvard.edu/wp-content/uploads/Levent_Alpoge.jpeg'}
# {'name': 'Larson, Hannah', 'title': 'Fellow', 'img': 'https://www.math.harvard.edu/wp-content/uploads/Hannah-Larson.jpg'}
# {'name': 'Yefremova, Anastasia', 'title': 'Publications Coordinator', 'img': 'https://www.math.harvard.edu/wp-content/uploads/Anastasia-Yefremova.jpg'}
# ________________________________________________________________________________________________________
# url: https://math.yale.edu/people/all-faculty
# method: tr
# length: 63
# ___________
# {'name': 'Jeffrey Brock', 'title': 'Dean, School of Engineering & Applied Science; FAS Dean of Science; Zhao and Ji Professor of Mathematics', 'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-886-1590976044.jpg?itok=wJR25f-W'}
# {'name': 'Boris Landa', 'title': 'Gibbs Assistant Professor, Applied Mathematics', 'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-1422-1565723397.jpg?itok=YeVjKlxZ'}
# {'name': 'Gregg Zuckerman', 'title': 'Professor Emeritus of Mathematics', 'img': 'https://math.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-326-1512660944.jpg?itok=R_yd-rH_'}
# ________________________________________________________________________________________________________
# url: https://www.brown.edu/academics/math/faculty
# method: tr
# length: 32
# ___________
# {'name': 'Dan Abramovich', 'title': 'L. Herbert Ballou University Professor', 'img': 'https://www.brown.edu/academics/math/sites/math/files/Abramovich_1.jpg'}
# {'name': 'Nicolaos\xa0Kapouleas', 'title': 'Professor', 'img': 'https://www.brown.edu/academics/math/sites/math/files/Nicos.jpg'}
# {'name': 'Isabel Vogt', 'title': 'Assistant Professor', 'img': 'https://www.brown.edu/academics/math/sites/math/files/IVogt.png'}
# ________________________________________________________________________________________________________
# url: https://math.dartmouth.edu/people/people-select.php?list=permanent
# method: children
# length: 24
# ___________
# {'name': 'Asher Auel', 'title': 'Associate Professor', 'img': '/photos/for-people-pages/auel_f00417z.jpg'}
# {'name': 'Rosa C. Orellana', 'title': 'Professor', 'img': '/photos/for-people-pages/orellana_d1158y2.jpg'}
# {'name': 'Peter Winkler', 'title': 'Professor', 'img': '/photos/for-people-pages/winkler_d16439n.jpg'}
# ________________________________________________________________________________________________________
# url: https://economics.dartmouth.edu/people
# method: class
# length: 45
# ___________
# {'name': 'Leila Agha', 'title': 'Assistant Professor of Economics', 'img': 'https://economics.dartmouth.edu/sites/department_economics.prod/files/styles/profile_portrait/public/leila_agha1a.jpg?itok=stPt7mTb'}
# {'name': 'Paul Novosad', 'title': 'Associate Professor of Economics', 'img': 'https://economics.dartmouth.edu/sites/department_economics.prod/files/styles/profile_portrait/public/pn.jpg?itok=lzYGaXrl'}
# {'name': 'Steven F. Venti', 'title': 'DeWalt H. 1921 and Marie H. Ankeny Professorship in Economic Policy and Professor of Economics, Emeritus', 'img': 'https://economics.dartmouth.edu/sites/department_economics.prod/files/styles/profile_portrait/public/Steve.Venti__0.jpg?itok=JDUfFGM7'}
# ________________________________________________________________________________________________________
# url: https://economics.yale.edu/people/faculty
# method: tr
# length: 51
# ___________
# {'name': 'Joseph Altonji', 'title': 'Thomas DeWitt Cuyler Professor of Economics', 'img': 'https://economics.yale.edu/sites/default/files/styles/grad_student_image/public/altonji-165x220_12_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0.jpg?itok=qjVSQ3nG'}
# {'name': 'Samuel Kortum', 'title': 'James Burrows Moffatt Professor of Economics', 'img': 'https://economics.yale.edu/sites/default/files/styles/grad_student_image/public/kortum_2012_5_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0.jpg?itok=XlPgjUmj'}
# {'name': 'Fabrizio Zilibotti', 'title': 'Tuntex Professor of International and Development Economics', 'img': 'https://economics.yale.edu/sites/default/files/styles/grad_student_image/public/zilibotti-news-crop_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0_0.jpg?itok=7OYT9Kiy'}
# ________________________________________________________________________________________________________
# url: https://english.columbia.edu/content/faculty#!#%2Fviews-display-37
# method: children
# length: 60
# ___________
# {'name': 'James  Adams', 'title': 'Professor of English and Comparative Literature', 'img': 'https://english.columbia.edu/sites/default/files/styles/cu_crop/public/content/pics/IMG_2214.jpg?h=dd9b2bd9&itok=SeRx78pC'}
# {'name': 'Julie Stone Peters', 'title': 'H. Gordon Garbedian Professor of English and Comparative Literature', 'img': 'https://english.columbia.edu/sites/default/files/styles/cu_crop/public/content/pics/Julie-Stone-Peters.JPG?h=0fdb99b7&itok=bqNq6WhR'}
# {'name': 'Jean Franco', 'title': 'Professor Emerita of English and Comparative Literature', 'img': 'https://english.columbia.edu/sites/default/files/styles/cu_crop/public/content/pics/JFranco.jpg?h=7afe7d72&itok=_a-3wyNn'}
# ________________________________________________________________________________________________________
# url: http://ealac.columbia.edu/people/professors/
# method: children
# length: 27
# ___________
# {'name': 'Nicholas Bartlett', 'title': 'Assistant Professor of Contemporary Chinese Culture and Society, Barnard College', 'img': 'http://ealac.columbia.edu/wp-content/uploads/2015/02/Bartlett_square-235x235.jpg'}
# {'name': 'Lydia H. Liu', 'title': 'Wun Tsun Tam Professor in the Humanities', 'img': 'http://ealac.columbia.edu/wp-content/uploads/2014/04/lydialiu-e1649431413453-235x235.jpg'}
# {'name': 'Madeleine Zelin', 'title': 'Dean Lung Professor of Chinese Studies', 'img': 'http://ealac.columbia.edu/wp-content/uploads/2017/02/Madeleine-Zelin-on-Mornngside-Drive-235x235.jpg'}
# ________________________________________________________________________________________________________
# url: https://english.yale.edu/people/ladder-faculty
# method: tr
# length: 42
# ___________
# {'name': 'Jessica Brantley', 'title': 'Professor of English, Department Chair', 'img': 'https://english.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-74-1563541874.jpg?itok=AZxBU2IY'}
# {'name': 'Stefanie Markovits', 'title': 'Professor of English, Director of Undergraduate Studies', 'img': 'https://english.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-22-1565275914.jpg?itok=FhUzef5I'}
# {'name': 'Ruth Yeazell', 'title': 'Sterling Professor of English', 'img': 'https://english.yale.edu/sites/default/files/styles/people_thumbnail/public/pictures/picture-168-1563217459.jpg?itok=Y6siHLoi'}
# ________________________________________________________________________________________________________
# url: https://www.ieor.columbia.edu/directory?gsarqfields%5Bbiotypetid%5D=30
# method: class
# length: 13
# ___________
# {'name': 'Ajit Agrawal', 'title': 'Adjunct Associate Professor', 'img': 'https://www.ieor.columbia.edu/files/seas/styles/300x300/public/content/bio_profile_image/2021/38/ajit-k.-agrawal_300.jpg?itok=1RsNQvJ0'}
# {'name': 'Kristen Bulatovic', 'title': 'Assistant Director of Finance & Operations', 'img': 'https://www.ieor.columbia.edu/files/seas/styles/300x300/public/content/bio_profile_image/2019/17/kb_headshot_edit.jpg?itok=MUj5wvkX'}
# {'name': 'Rachel  Cummings', 'title': 'ASSISTANT PROFESSOR OF INDUSTRIAL ENGINEERING AND OPERATIONS RESEARCH', 'img': 'https://www.ieor.columbia.edu/files/seas/styles/300x300/public/content/bio_profile_image/2021/10/rachel.jpeg?itok=J5622ZXy'}
# ________________________________________________________________________________________________________
# url: https://www.cs.columbia.edu/people/faculty/
# method: class
# length: 72
# ___________
# {'name': 'Alman, Josh', 'title': 'Assistant Professor of Computer Science', 'img': 'https://www.cs.columbia.edu/wp-content/themes/columbia-cs/assets/img/cv.png'}
# {'name': 'Papadimitriou, Christos H', 'title': 'The Donovan Family Professor', 'img': 'https://www.cs.columbia.edu/wp-content/themes/columbia-cs/assets/img/cv.png'}
# {'name': 'Yemini, Yechiam', 'title': 'Professor Emeritus', 'img': 'https://www.cs.columbia.edu/wp-content/themes/columbia-cs/assets/img/www.png'}
# ________________________________________________________________________________________________________
# url: https://afamstudies.columbia.edu/content/people
# method: children
# length: 27
# ___________
# {'name': 'Kellie E. Jones', 'title': 'Hans Hofmann Professor of Modern Art, Department of Art History and Archaeology; Chair African American and African Diaspora Studies', 'img': 'https://afamstudies.columbia.edu/sites/default/files/styles/cu_crop/public/content/k-jones.png?itok=OTKxY6Vu'}
# {'name': 'Gilbert M. Khadiagala', 'title': 'Jan Smuts Professor of International Relations and Director of the Centre for the Study of the United States (ACSUS) at the University of Witwatersrand, Johannesburg, South Africa', 'img': 'https://afamstudies.columbia.edu/sites/default/files/styles/cu_crop/public/content/Research%20Affiliates/Kadiagala.jpg?itok=eR8QawKc'}
# {'name': 'Tumelo Mosaka', 'title': 'Mellon Project Director and Curator, African American and Afircan Diaspora Studies', 'img': 'https://afamstudies.columbia.edu/sites/default/files/styles/cu_crop/public/content/Tumelo_Mosaka_Headshot.jpg?h=be01d3df&itok=j4Ak2_Yf'}
# ________________________________________________________________________________________________________
# url: https://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations/people/faculty
# method: children
# length: 49
# ___________
# {'name': 'Santiago Balseiro', 'title': 'Daniel W. Stanton Associate Professor of Business', 'img': '/cbs-directory/photo/srb2155/110x90'}
# {'name': 'Yilun Chen', 'title': 'Postdoctoral Research Scholar', 'img': '/cbs-directory/photo/yc4054'}
# {'name': 'Gustavo Vulcano', 'title': 'Adjunct Professor of Business', 'img': '/cbs-directory/photo/gjv9'}
# ________________________________________________________________________________________________________
# url: https://arth.sas.upenn.edu/people/standing-faculty
# method: children
# length: 17
# ___________
# {'name': 'Shira  Brisman', 'title': 'Assistant Professor in Early Modern Art', 'img': 'https://arth.sas.upenn.edu/sites/default/files/styles/profile-thumb/public/shira%20headshot.jpg?itok=bwaB9oel'}
# {'name': 'David Young Kim', 'title': 'Associate Professor of History of Art', 'img': 'https://arth.sas.upenn.edu/sites/default/files/styles/profile-thumb/public/DK_profile.jpg?itok=V4YoYrQJ'}
# {'name': 'Chenshu  Zhou', 'title': 'Assistant Professor of History of Art', 'img': 'https://arth.sas.upenn.edu/sites/default/files/styles/profile-thumb/public/headshot-web.jpg?itok=A0tmxZsJ'}
# ________________________________________________________________________________________________________
# url: https://www.english.upenn.edu/people/faculty
# method: class
# length: 72
# ___________
# {'name': 'Julia  Alekseyeva', 'title': 'Assistant Professor of English and Cinema & Media Studies', 'img': 'https://www.english.upenn.edu/sites/default/files/styles/img-circle/public/people/photo/official/cropped/julia1.jpg?itok=bQg5YNvD'}
# {'name': 'Roger  Chartier', 'title': 'Annenberg Visiting Professor in History and Professor at the College de France', 'img': 'https://www.english.upenn.edu/sites/default/files/styles/img-circle/public/people/photo/220px-Chartier_Roger.jpg?itok=-m_jYQCk'}
# {'name': 'Wendy  Steiner', 'title': 'Richard L. Fisher Professor of English', 'img': 'https://www.english.upenn.edu/sites/default/files/styles/img-circle/public/people/photo/wsteiner.jpg?itok=jd5d5-ZX'}
# ________________________________________________________________________________________________________
# url: https://www.ling.upenn.edu/people/faculty
# method: class
# length: 35
# ___________
# {'name': 'Eugene Buckley', 'title': 'Associate Professor; Graduate Chair', 'img': '/sites/default/files/styles/profile_list/public/2019-11/Buckley.png?itok=hvkNedJc'}
# {'name': 'Delphine Dahan', 'title': 'Associate Professor, Psychology', 'img': '/sites/default/files/styles/profile_list/public/2020-05/Delphine%20Dahan%20Cropped.jpg?itok=Y2LN1g3f'}
# {'name': 'Harold Schiffman', 'title': 'Professor Emeritus of Dravidian Linguistics and Culture, South Asia Studies', 'img': '/sites/default/files/styles/profile_list/public/2019-11/Schiffman.jpg?itok=0ln8qUHa'}
# ________________________________________________________________________________________________________
# url: https://hss.sas.upenn.edu/people
# method: children
# length: 13
# ___________
# {'name': 'Robert A. Aronowitz', 'title': 'Professor', 'img': 'https://hss.sas.upenn.edu/system/files/styles/profile-thumb/private/Aronowitz-portrait1.jpg?itok=c3OrNgjj'}
# {'name': 'Beth  Linker', 'title': 'Associate Professor', 'img': 'https://hss.sas.upenn.edu/system/files/styles/profile-thumb/private/Screen%20Shot%202019-10-26%20at%2012.00.21%20PM.jpg?itok=sUpqzjYA'}
# {'name': 'Adelheid  Voskuhl', 'title': 'Associate Professor', 'img': 'https://hss.sas.upenn.edu/system/files/styles/profile-thumb/private/voskuhl.jpg?itok=ld1bk732'}
# ________________________________________________________________________________________________________
# url: https://english.dartmouth.edu/people
# method: class
# length: 42
# ___________
# {'name': 'Ingrid Becker', 'title': 'Lecturer, Department of English and Creative Writing', 'img': 'https://english.dartmouth.edu/sites/department_english/files/styles/profile_portrait/public/image0_1.jpeg?itok=Oew7-MVe'}
# {'name': 'Emi Sawada', 'title': 'Lecturer', 'img': 'https://english.dartmouth.edu/sites/department_english/files/styles/profile_portrait/public/faculty_profile_pic_0.jpg?itok=WwnlQTm5'}
# {'name': 'Peter W. Travis', 'title': 'Professor of English, Emeritus', 'img': 'https://english.dartmouth.edu/sites/department_english/files/styles/profile_portrait/public/peter_travis.jpg?itok=g2ASNUvU'}
# ________________________________________________________________________________________________________
# url: https://german.dartmouth.edu/people
# method: class
# length: 14
# ___________
# {'name': 'Gerd Gemünden', 'title': 'Professor of German Studies', 'img': 'https://german.dartmouth.edu/sites/german.prod/files/styles/profile_portrait/public/20200113_gemunden_eb_062.jpg?itok=b6U_ysgx'}
# {'name': 'Ellis Shookman', 'title': 'Professor of German Studies', 'img': 'https://german.dartmouth.edu/sites/german.prod/files/styles/profile_portrait/public/ers_nehru_0.jpg?itok=zfB4_Tja'}
# {'name': 'Ulrike Rainer', 'title': 'Associate Professor Emerita', 'img': 'https://german.dartmouth.edu/sites/german.prod/files/styles/profile_portrait/public/ulli2011.jpg?itok=Y60BQtNZ'}
# ________________________________________________________________________________________________________
# url: https://ascl.dartmouth.edu/people
# method: class
# length: 24
# ___________
# {'name': 'Sunglim Kim', 'title': 'Associate Professor of Art History', 'img': 'https://ascl.dartmouth.edu/sites/asian_societies_cultures_languages.prod/files/styles/profile_portrait/public/648_original.jpg?itok=xkBOatZ9'}
# {'name': 'Douglas E. Haynes', 'title': 'Professor of History', 'img': 'https://ascl.dartmouth.edu/sites/asian_societies_cultures_languages.prod/files/styles/profile_portrait/public/184_original.jpg?itok=jpev5M7F'}
# {'name': 'Seong-Kon Kim', 'title': 'Visiting Scholar', 'img': 'https://ascl.dartmouth.edu/sites/asian_societies_cultures_languages.prod/files/styles/profile_portrait/public/asian_societies_cultures_languages/images/seong-kon_kim.jpg?itok=ECxpT8EH'}
# ________________________________________________________________________________________________________
# url: https://chemistry.dartmouth.edu/people
# method: class
# length: 40
# ___________
# {'name': 'Ivan Aprahamian', 'title': 'Professor of Chemistry', 'img': 'https://chemistry.dartmouth.edu/sites/department_chemistry/files/styles/profile_portrait/public/20140915-aprahamian-095_597_0_1.jpg?itok=bJ-Hcda5'}
# {'name': 'Margie Ackerman', 'title': 'Professor of Engineering', 'img': 'https://chemistry.dartmouth.edu/sites/department_chemistry/files/styles/profile_portrait/public/margie-ackerman.jpg?itok=_1pxTRuO'}
# {'name': 'Alla Antonova Arias', 'title': 'Laboratory Assistant', 'img': 'https://chemistry.dartmouth.edu/sites/department_chemistry/files/styles/profile_portrait/public/default_images/facdir_default.jpg?itok=SwM_V3IC'}
# ________________________________________________________________________________________________________
# url: https://web.cs.dartmouth.edu/people
# method: bf
# length: 135
# ___________
# {'name': 'Michael Cohen', 'title': 'adjuncts', 'img': 'https://web.cs.dartmouth.edu/sites/department_computer_science/files/styles/profile_portrait/public/department_computer_science/images/michael-cohen_full-e1558722195588.jpg?itok=gRntaiDd'}
# {'name': 'Almas Abdibayev', 'title': 'PhD Students', 'img': 'https://web.cs.dartmouth.edu/sites/department_computer_science/files/styles/profile_portrait/public/default_images/facdir_default.jpg?itok=agRIusm7'}
# {'name': 'Susan Perry Cable', 'title': 'admin staff', 'img': 'https://web.cs.dartmouth.edu/sites/department_computer_science/files/styles/profile_portrait/public/image001.jpg?itok=qmdr9yb7'}
# ________________________________________________________________________________________________________
# url: https://ealc.fas.harvard.edu/people/taxonomy/term/6536
# method: children
# length: 12
# ___________
# {'name': 'Ryuichi Abe', 'title': 'Reischauer Institute Professor of Japanese Religions', 'img': '//static.projects.iq.harvard.edu/files/styles/profile_thumbnail/public/ealc/files/abe_1.jpg?m=1629300367&itok=jOn4X98o'}
# {'name': 'Carter Eckert', 'title': 'Yoon Se Young Professor of Korean History', 'img': '//static.projects.iq.harvard.edu/files/styles/profile_thumbnail/public/ealc/files/unspecified.jpg?m=1641403028&itok=W0-ssacO'}
# {'name': 'Janet Gyatso', 'title': 'Hershey Professor of Buddhist Studies', 'img': '//static.projects.iq.harvard.edu/files/styles/profile_thumbnail/public/ealc/files/gyatso_1.jpg?m=1641393429&itok=s8hKrZ3U'}
# ________________________________________________________________________________________________________
# url: https://english.fas.harvard.edu/our-people
# method: class
# length: 53
# ___________
# {'name': 'Robert Brustein', 'title': 'Professor of English, Emeritus', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/english/files/brustein.jpg?m=1533216969&itok=Bbwm0Zxv'}
# {'name': 'Katie Daily', 'title': 'Lecturer on English', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/english/files/conference_photo.jpg?m=1622661517&itok=YqJlQ52w'}
# {'name': 'Andrew Warren', 'title': 'Associate of the Department of English', 'img': '//static.hwpi.harvard.edu/files/styles/profile_thumbnail/public/english/files/warren1-e1461168731665.jpg?m=1561987225&itok=kEHX7fzo'}
# ________________________________________________________________________________________________________
# url: https://philosophy.fas.harvard.edu/faculty-1
# method: bf
# length: 21
# ___________
# {'name': 'Jeff Behrends', 'title': 'Associate Senior Lecturer on Philosophy', 'img': '//static.projects.iq.harvard.edu/files/styles/os_files_small/public/phildept/files/behrends-rlportrait-2019.jpg?m=1628026121&itok=FrCGo-hi'}
# {'name': 'Jeff Behrends', 'title': 'Associate Senior Lecturer on Philosophy', 'img': '//static.projects.iq.harvard.edu/files/styles/os_files_small/public/phildept/files/behrends-rlportrait-2019.jpg?m=1628026121&itok=FrCGo-hi'}
# {'name': 'Jeff Behrends', 'title': 'Associate Senior Lecturer on Philosophy', 'img': '//static.projects.iq.harvard.edu/files/styles/os_files_small/public/phildept/files/behrends-rlportrait-2019.jpg?m=1628026121&itok=FrCGo-hi'}
# ________________________________________________________________________________________________________
# url: https://cals.cornell.edu/global-development/about/people/faculty
# method: class
# length: 85
# ___________
# {'name': 'Mathew Abraham', 'title': 'Assistant Director, Tata-Cornell Institute', 'img': '/sites/default/files/styles/faculty/public/2021-12/matthew-abraham.jpg?h=ba0f66d9&itok=rLKrebhR'}
# {'name': 'Jeffrey Perry', 'title': 'Senior Lecturer', 'img': '/sites/default/files/styles/faculty/public/2021-03/jefdf-perry-1200-square.jpg?h=936b56d8&itok=0ajr-jIC'}
# {'name': 'Raghav Puri', 'title': 'Postdoctoral Associate, Tata-Cornell Institute', 'img': '/sites/default/files/styles/faculty/public/2021-12/raghav-puri.jpeg?h=89cc02a0&itok=LGAGa-r2'}
# ________________________________________________________________________________________________________
# url: https://cals.cornell.edu/landscape-architecture/people
# method: class
# length: 19
# ___________
# {'name': 'Timothy Baird', 'title': 'Department Chair, Professor', 'img': '/sites/default/files/styles/faculty/public/2021-10/photoctb2.jpeg?h=d0dd59e8&itok=01Erk8fl'}
# {'name': 'Zaneta Hong', 'title': 'Assistant Professor', 'img': '/sites/default/files/styles/faculty/public/2020-11/zaneta-hong_original-smaller.jpg?h=fb6e11ee&itok=fdNgfz5U'}
# {'name': 'Kristie Milliman', 'title': 'Undergraduate and Graduate Field Assistant', 'img': None}
# ________________________________________________________________________________________________________
# url: https://aap.cornell.edu/academics/faculty
# method: children
# length: 124
# ___________
# {'name': 'Nidaa Aboulhosn', 'title': 'Art, Visiting Critic', 'img': 'https://aap.cornell.edu/sites/default/files/styles/portrait-medium/public/person/aboulhosn-tannourine-xs_300x.jpg?itok=Ep5svpfC'}
# {'name': 'Greg Keeffe', 'title': 'Architecture, Thomas J Baird Visiting Professor', 'img': 'https://aap.cornell.edu/sites/default/files/styles/portrait-medium/public/person/Greg.jpg?itok=Py7IFK0_'}
# {'name': 'Sasa Zivkovic', 'title': 'Architecture, Assistant Professor', 'img': 'https://aap.cornell.edu/sites/default/files/styles/portrait-medium/public/person/prov-Sasa%20Zivkovic_270x270.jpg?itok=evpaQKwa'}
# ________________________________________________________________________________________________________
# url: https://anthropology.cornell.edu/anthropology-faculty
# method: children
# length: 21
# ___________
# {'name': 'Chloe Ahmann', 'title': 'Assistant Professor', 'img': 'https://people.as.cornell.edu/files/second/styles/person_image/public/chloe-ahmann.jpeg?itok=_5Fc-rA6'}
# {'name': 'Viranjini P Munasinghe', 'title': 'Associate Professor', 'img': 'https://people.as.cornell.edu/files/second/styles/person_image/public/viranjini-p-munasinghe.jpg?itok=W-bsj_BX'}
# {'name': 'Andrew C. Willford', 'title': 'Professor', 'img': 'https://people.as.cornell.edu/files/second/styles/person_image/public/andrew-c-willford.jpg?itok=Cx1w7A2W'}

# %%
also_fails = []
also_fails.append("https://www.math.columbia.edu/people/faculty-by-rank/") # name outside the class
fails.extend(also_fails)

# %%
success_rate = 1-len(fails)/len(urls)
print(f"sucess rate for ({len(urls)} pages) = {success_rate:.2f}")
# Out:
# sucess rate for (39 pages) = 0.92

# %%
fails
# Out:
# ['https://anthropology.columbia.edu/content/faculty-directory',
#  'https://arts.columbia.edu/faculty',
#  'https://www.math.columbia.edu/people/faculty-by-rank/']

# %% [markdown]
# # Notes

# %% [markdown]
# Failed because imgs are embedded as background-image:
# https://anthropology.columbia.edu/content/faculty-directory
# https://arts.columbia.edu/faculty
#
# Faculty name not in the class:
# https://www.math.columbia.edu/people/faculty-by-rank/
#
# All the ones that are not failed at least found profiles in the first page
#
# --------------------------------------------------------------------------
# Next step: find a way to load all the pages
