# %%
from scraping import Scraping
import sys
import json

# %% [markdown]
# # Scraping

# %%
scraping = Scraping()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 100.0.4896
# [WDM] - Get LATEST chromedriver version for 100.0.4896 google-chrome
# [WDM] - Driver [C:\Users\GuoshengCai\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache

# %%
in_path = sys.path[0] + '/../data/cornell/cornell_directories_sans_med.json'
out_path = sys.path[0] + '/../data/cornell/cornell_w_profiles.json'
cornell = scraping.scrape_faculty(in_path, out_path)

# %% [markdown]
# # Result

# %%
completely_failed = []
for department in cornell:
    if department.get('success') == False:
        completely_failed.append(department.get('faculty_page'))
    else:
        res = department.get('profiles')
        print("____________________________________________")
        print(f"url: {department.get('faculty_page')}")
        print(f"len: {len(res)}")
        print(res[1])
        print(res[-1])
# Out:
# ____________________________________________
# url: https://cals.cornell.edu/animal-science/about/people
# len: 45
# {'name': 'Debbie Cherney', 'title': 'Professor', 'img': '/sites/default/files/styles/faculty/public/2021-01/animal-science-debbie-cherney4x6.png?h=761f4e97&itok=FGb9fpjl'}
# {'name': 'Donna Wakeman', 'title': 'Administrative Assistant to the Chair', 'img': '/sites/default/files/styles/faculty/public/2021-01/donna-wakeman4x6.png?h=8ad61ead&itok=MXUIgp6_'}
# ____________________________________________
# url: https://cals.cornell.edu/biological-environmental-engineering/about/people/faculty
# len: 19
# {'name': 'Lindsay Anderson', 'title': 'Associate Professor', 'img': '/sites/default/files/styles/faculty/public/2019-12/tumblr_nmhyjdmekh1s5oeaso4_540.png?h=89499783&itok=fuqUMDM7'}
# {'name': 'Mingming Wu', 'title': 'Professor', 'img': None}
# ____________________________________________
# url: https://compbio.cornell.edu/people/faculty
# len: 13
# ...

# %%
completely_failed
# Out:
# ['https://dyson.cornell.edu/faculty-research/search/',
#  'https://www.human.cornell.edu/dns/about/people',
#  'https://sha.cornell.edu/faculty-research/search/']

# %%
failed_directories = []
for department in cornell:
    url = department.get('faculty_page')
    if url in completely_failed:
        failed_directories.append(department)

# %%
with open(sys.path[0] + '/../data/cornell/failed_directories.json', 'w') as f:
    json.dump(failed_directories, f)

# %%
failed_rate = len(failed_directories) / len(cornell)
print(f"success rate for testing ({len(cornell)} departments)= {1 - failed_rate:.2f}")
# Out:
# success rate for testing (61 departments)= 0.95
