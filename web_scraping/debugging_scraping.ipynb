# %%
from scraping_helpers import ScrapingHelpers
from scraping_tr import ScrapingTr
from scraping_class_name import ScrapingClass
from scraping_children import ScrapingChildren
from scraping_bf import ScrapingBf
from scraping import Scraping
import sys
import json
import re

# %%
helpers = ScrapingHelpers()
tr = ScrapingTr()
class_name = ScrapingClass()
children = ScrapingChildren()
bf = ScrapingBf()
s = Scraping()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 100.0.4896
# [WDM] - Get LATEST chromedriver version for 100.0.4896 google-chrome
# [WDM] - Driver [C:\Users\GuoshengCai\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache

# %% [markdown]
# # Testing

# %%
urls = ["https://stat.columbia.edu/department-directory/faculty-and-lecturers/", 
         "https://statistics.wharton.upenn.edu/faculty/faculty-list/",
         "https://statistics.fas.harvard.edu/faculty",
         "https://statistics.yale.edu/people",
         "https://www.brown.edu/academics/public-health/biostats/people/faculty",
         "https://stat.cornell.edu/people/faculty",
         "https://www.math.columbia.edu/people/faculty-by-rank/",
         "https://www.math.upenn.edu/people/standing-faculty",
         "https://www.math.harvard.edu/people/",
         "https://math.yale.edu/people/all-faculty",
         "https://www.brown.edu/academics/math/faculty", 
         "https://math.dartmouth.edu/people/people-select.php?list=permanent",
         "https://economics.dartmouth.edu/people",
         "https://economics.yale.edu/people/faculty",
         "https://english.columbia.edu/content/faculty#!#%2Fviews-display-37",
         "http://ealac.columbia.edu/people/professors/",
         "https://english.yale.edu/people/ladder-faculty",
         "https://www.ieor.columbia.edu/directory?gsarqfields%5Bbiotypetid%5D=30",
         "https://www.cs.columbia.edu/people/faculty/",
         "https://afamstudies.columbia.edu/content/people",
         "https://anthropology.columbia.edu/content/faculty-directory",
         "https://www.biochem.cuimc.columbia.edu/research/research-faculty",
         "https://www8.gsb.columbia.edu/faculty-research/divisions/decision-risk-operations/people/faculty",
         "https://arts.columbia.edu/film/",
         "https://arth.sas.upenn.edu/people/standing-faculty",
         "https://www.english.upenn.edu/people/faculty",
         "https://www.ling.upenn.edu/people/faculty",
         "https://hss.sas.upenn.edu/people",
         "https://english.dartmouth.edu/people",
         "https://german.dartmouth.edu/people",
         "https://ascl.dartmouth.edu/people",
         "https://chemistry.dartmouth.edu/people",
         "https://web.cs.dartmouth.edu/people",
         "https://ealc.fas.harvard.edu/people/taxonomy/term/6536",
         "https://english.fas.harvard.edu/our-people",
         "https://philosophy.fas.harvard.edu/faculty-1",
         "https://cals.cornell.edu/global-development/about/people/faculty",
         "https://cals.cornell.edu/landscape-architecture/people",
         "https://aap.cornell.edu/academics/faculty",
         "https://anthropology.cornell.edu/anthropology-faculty"
        ]

# %%
works = []
fails = []
for url in urls[:20]:
    try:
        res = s.get_department_info(url)
        item = {'url': url, 'res':res}
        works.append(item)
    except:
        fails.append(url)

# %%
fails
# Out:
# ['https://www.math.columbia.edu/people/faculty-by-rank/']

# %%
works
# Out:
# [{'url': 'https://stat.columbia.edu/department-directory/faculty-and-lecturers/',
#   'res': [{'name': 'David Blei',
#     'title': 'Professor',
#     'img': 'https://stat.columbia.edu/wp-content/uploads/connections-images/david-blei/Blei-David-1.jpg'},
#    {'name': 'John P. Cunningham',
#     'title': 'Professor',
#     'img': 'https://stat.columbia.edu/wp-content/uploads/connections-images/john-cunningham/cunningham_original.jpg'},
#    {'name': 'Richard A. Davis',
#     'title': 'Howard Levene Professor',
#     'img': 'https://stat.columbia.edu/wp-content/uploads/connections-images/richard-davis/Davis-Richard.jpg'},
#    {'name': 'Andrew Gelman',
#     'title': 'Higgins Professor of Statistics',
#     'img': 'https://stat.columbia.edu/wp-content/uploads/connections-images/andrew-gelman/Gelman-Andrew-2.png'},
#    {'name': 'Ioannis Karatzas',
#     'title': 'Professor',
# ...

# %% [markdown]
# # Debugging

# %%
with open(sys.path[0] + '/../data/failed_directories.json') as f:
    columbia = json.load(f)

# %%
i = 0
for department in columbia:
    print(i, department.get('faculty_page'))
    i += 1
# Out:
# 0 https://arthistory.barnard.edu/full-time-faculty
# 1 https://arthistory.columbia.edu/content/full-time-faculty
# 2 https://www.biology.columbia.edu/people/faculty-department
# 3 https://classics.barnard.edu/faculty-5
# 4 http://classics.columbia.edu/profiles
# 5 http://ealac.columbia.edu/people/
# 6 https://e3b.columbia.edu/faculty/
# 7 https://economics.barnard.edu/faculty-and-staff-0
# 8 https://www.ee.columbia.edu/people-by-type/faculty
# 9 http://history.columbia.edu/faculty/
# 10 https://laic.columbia.edu/content/affiliated-faculty
# 11 https://microbiology.columbia.edu/faculty
# 12 https://philosophy.barnard.edu/faculty
# 13 https://pe.barnard.edu/pe-faculty
# 14 https://polisci.barnard.edu/faculty
# 15 https://religion.barnard.edu/faculty-religion
# 16 https://slavic.barnard.edu/slavic-faculty-hours
# 17 https://slavic.columbia.edu/faculty
# 18 https://spanish.barnard.edu/faculty-spanish
# 19 https://theatre.barnard.edu/faculty-2

# %%
# arthistory.columbia.edu
t = columbia[1].get('faculty_page')
soups = helpers.get_soups(t, helpers.get_driver())
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 100.0.4896
# [WDM] - Get LATEST chromedriver version for 100.0.4896 google-chrome
# [WDM] - Driver [C:\Users\GuoshengCai\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache

# %%
soup = soups[0]

# %%
pattern = re.compile(r"(?i).*(Professor|Lecturer|Student|Director|Fellow|Adjunct|Assistant|Coordinator|Postgraduate|Postdoctoral|Scientist|Visiting|Associate|Staff|PhD).*")
elements = soup.find_all(text=pattern)

# %%
elements[50]
# Out:
# '\nLisa and Bernard Selz Associate Professor in Pre-Columbian Art History and Archaeology'

# %%
res = s.get_department_info(t)

# %%
soups = helpers.get_soups(t, helpers.get_driver())
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 100.0.4896
# [WDM] - Get LATEST chromedriver version for 100.0.4896 google-chrome
# [WDM] - Driver [C:\Users\GuoshengCai\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache

# %%
soups
# Out:
# [<body class="html not-front not-logged-in page-taxonomy page-taxonomy-term page-taxonomy-term- page-taxonomy-term-27 context-people responsive-menus-load-processed omega-mediaqueries-processed responsive-layout-wide"><div id="omega-media-query-dummy"><style media="all">#omega-media-query-dummy { position: relative; z-index: -1; }</style><!--[if (lt IE 9)&(!IEMobile)]><style media="all">#omega-media-query-dummy { z-index: 1; }</style><![endif]--><style media="all and (min-width: 740px) and (min-device-width: 740px), (max-device-width: 800px) and (min-width: 740px) and (orientation:landscape)">#omega-media-query-dummy { z-index: 0; }</style><style media="all and (min-width: 980px) and (min-device-width: 980px), all and (max-device-width: 1024px) and (min-width: 1024px) and (orientation:landscape)">#omega-media-query-dummy { z-index: 1; }</style><style media="all and (min-width: 1220px)">#omega-media-query-dummy { z-index: 2; }</style></div><div class="" id="cu-privacy-notice"><div id=
# ...

# %%
len(soups)
# Out:
# 2

# %%
res = class_name.get_department_info_class(soups)

# %%
len(res)
# Out:
# 13

# %%
soups = helpers.get_soups(t, helpers.get_driver())
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 100.0.4896
# [WDM] - Get LATEST chromedriver version for 100.0.4896 google-chrome
# [WDM] - Driver [C:\Users\GuoshengCai\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache

# %%
soups[0]
# Out:
# <body class="cu-profile-academic node-cu_landing_page path-node page-node-type-cu-landing-page has-glyphicons ng-scope break992 banner-loaded" data-breakpoint="{ 0:'mobile', 767:'break768', 991:'break992' }" data-ng-class="[global.controller, search.widgetOpen ? 'search-open' : '', (global.controller == 'search' &amp;&amp; gcse.status) ? 'search-ready' : '', nav.mobileOpen ? 'mobile-nav-open' : '', page.overlayShown ? 'overlay-shown' : '', gsa.classes]" data-ng-controller="global">
#     <a class="visually-hidden focusable skip-link" href="#main-content" id="top">
#       Skip to main content
#     </a>
#
#
#       <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#
#     <div class="region region-alerts">
#     <section class="cu_alert_client_global_alerts block clearfix" id="block-globalalerts-cu-academic1">
#
#
#
#       <div id="alerts"></div>
#   </section>
#
#
#   </div>
#
#
# ...

# %%
dynamic-grid-listing-item grid-item angular-animate ng-trans ng-trans-fade-down ng-scope grid-item-with-image
dynamic-grid-listing-item grid-item angular-animate ng-trans ng-trans-fade-down ng-scope grid-item-with-image
