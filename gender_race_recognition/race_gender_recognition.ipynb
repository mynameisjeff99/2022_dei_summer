# %%
import sys
import json
from gender_race_recognition import GenderRaceRecognition
import pandas as pd

# %%
recognition = GenderRaceRecognition()

# %% [markdown]
# # Dartmouth

# %%
in_path = sys.path[0] + '/../data/dartmouth/dartmouth_test_processed.json'
out_path = sys.path[0] + '/../data/dartmouth/dartmouth_test_processed_deteched.json'

# %%
recognition.detech_gender_race(in_path, out_path)
# Out:
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.59it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.57it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.54it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.78it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.28it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.97it/s]
# ...

# %% [markdown]
# # Columbia

# %%
in_path = sys.path[0] + '/../data/columbia/columbia_test_processed.json'
out_path = sys.path[0] + '/../data/columbia/columbia_test_processed_deteched.json'

# %%
recognition.detech_gender_race(in_path, out_path)
# Out:
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: gender:   0%|                                                                            | 0/2 [00:00<?, ?it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.12it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.45it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: gender:   0%|                                                                            | 0/2 [00:00<?, ?it/s]
# ['api', 'black', 'hispanic', 'white']
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.09it/s]
# ['api', 'black', 'hispanic', 'white']
# ...

# %% [markdown]
# # Yale

# %%
in_path = sys.path[0] + '/../data/yale/yale_w_profiles_processed.json'
out_path = sys.path[0] + '/../data/yale/yale_w_profiles_processed_deteched.json'

# %%
recognition.detech_gender_race(in_path, out_path)
# Out:
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.84it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.32it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.58it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.01it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.55it/s]
# ['api', 'black', 'hispanic', 'white']
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.30it/s]
# ...

# %% [markdown]
# # Add rank (only needed for columbia and dartmouth)

# %%
sys.path.insert(0, sys.path[0] + '/../data_cleaning')

# %%
from profile_cleaning import ProfileCleaning

# %%
p_cleaning = ProfileCleaning()

# %%
with open(sys.path[0] + '/../data/columbia/columbia_test_processed_deteched.json', 'r') as f:
    columbia = json.load(f)

# %%
for department in columbia:
    profiles = department.get('profiles')
    if profiles is not None:
        for p in profiles:
            p_cleaning.process_title(p)

# %%
pd.DataFrame(columbia[3].get('profiles'))
# Out:
#                name                                              title  \
# 0  Nadia Abu El-Haj                          Professor of Anthropology
# 1    Severin Fowles  Chair of American Studies, Associate Professor...
# 2     E. Mara Green                                Assistant Professor
# 3          Gina Jae                           Term Assistant Professor
# 4      Brian Larkin  Professor of Anthropology/Chair,  Columbia Uni...
# 5       J.C. Salyer  Director, Human Rights Program |\n\nAssistant ...
# 6    Lesley A Sharp  Barbara Chamberlain & Helen Chamberlain Josefs...
# 7     Camilla Sturm                           Term Assistant Professor
# 8        Paige West           The Claire Tow Professor Of Anthropology
#
#                                                  img first_name middle_name  \
# 0  https://anthropology.barnard.edu/sites/default...      Nadia         Abu
# 1  https://anthropology.barnard.edu/sites/default...    Severin        None
# ...

# %%
with open(sys.path[0] + '/../data/columbia/columbia_test_processed_deteched.json', 'w') as f:
    json.dump(columbia, f)

# %%
with open(sys.path[0] + '/../data/dartmouth/dartmouth_test_processed_deteched.json', 'r') as f:
    dartmouth = json.load(f)

# %%
for department in dartmouth:
    profiles = department.get('profiles')
    if profiles is not None:
        for p in profiles:
            p_cleaning.process_title(p)

# %%
with open(sys.path[0] + '/../data/dartmouth/dartmouth_test_processed_deteched.json', 'w') as f:
    json.dump(dartmouth, f)

# %%
pd.DataFrame(dartmouth[5].get('profiles'))
# Out:
#                      name                                 title  \
# 0         Ivan Aprahamian                Professor of Chemistry
# 1        Robert S. Cantor                Professor of Chemistry
# 2         David S. Glueck                Professor of Chemistry
# 3             Chenfeng Ke      Assistant Professor or Chemistry
# 4             F. Jon Kull        Rodgers Professor of Chemistry
# 5      Glenn C. Micalizio  New Hampshire Professor of Chemistry
# 6          Dale F. Mierke                Professor of Chemistry
# 7     Katherine A. Mirica      Associate Professor of Chemistry
# 8   Ekaterina V. Pletneva                Professor of Chemistry
# 9       Michael J. Ragusa      Assistant Professor of Chemistry
# 10        Paul Robustelli      Assistant Professor of Chemistry
# 11   Christopher Sandford      Assistant Professor of Chemistry
# 12    Catherine O. Welder                       Senior Lecturer
# 13         Dean E. Wilcox                Professor of Chemistry
# ...
