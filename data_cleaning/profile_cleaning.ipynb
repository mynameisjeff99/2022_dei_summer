# %%
import sys
import json
from profile_cleaning import ProfileCleaning

# %%
p_cleaning = ProfileCleaning()

# %% [markdown]
# # Columbia

# %%
in_path = sys.path[0] + '/../data/columbia/columbia_test_sans_processing.json'
out_path = sys.path[0] + '/../data/columbia/columbia_test_processed.json'
columbia_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
columbia_processed[5]
# Out:
# {'department': 'Applied Physics and Applied Mathematics Department',
#  'url': 'http://apam.columbia.edu/',
#  'faculty_page': 'https://www.apam.columbia.edu/directory?gsarqfields%5Bbiotypetid%5D=30',
#  'success': True,
#  'profiles': [{'name': 'William Bailey',
#    'title': 'ASSOCIATE PROFESSOR OF MATERIALS SCIENCE AND ENGINEERING IN THE DEPARTMENT OF APPLIED PHYSICS AND APPLIED MATHEMATICS',
#    'img': 'https://www.apam.columbia.edu/files/seas/styles/300x300/public/content/bio_profile_image/2019/29/bailey_300.jpg?itok=Ay-w6css',
#    'rank': 'associate professor',
#    'first_name': 'William',
#    'middle_name': None,
#    'last_name': 'Bailey'},
#   {'name': 'Katayun Barmak',
#    'title': 'PHILIPS ELECTRONICS PROFESSOR OF APPLIED PHYSICS AND APPLIED MATHEMATICS',
#    'img': 'https://www.apam.columbia.edu/files/seas/styles/300x300/public/content/bio_profile_image/2017/14/barmak-preferred-1.jpg?itok=SIUjRpFt',
#    'rank': 'professor',
#    'first_name': 'Katayun',
# ...

# %% [markdown]
# # Dartmouth

# %%
in_path = sys.path[0] + '/../data/dartmouth/dartmouth_test_sans_processing.json'
out_path = sys.path[0] + '/../data/dartmouth/dartmouth_test_processed.json'
dartmouth_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
dartmouth_processed[5]
# Out:
# {'department': 'Chemistry',
#  'url': 'https://chemistry.dartmouth.edu/',
#  'faculty_page': 'https://chemistry.dartmouth.edu/people?field_people_local_tags_tid=1626',
#  'success': True,
#  'profiles': [{'name': 'Ivan Aprahamian',
#    'title': 'Professor of Chemistry',
#    'img': 'https://chemistry.dartmouth.edu/sites/department_chemistry/files/styles/profile_portrait/public/20140915-aprahamian-095_597_0_1.jpg?itok=bJ-Hcda5',
#    'rank': 'professor',
#    'first_name': 'Ivan',
#    'middle_name': None,
#    'last_name': 'Aprahamian'},
#   {'name': 'Robert S. Cantor',
#    'title': 'Professor of Chemistry',
#    'img': 'https://chemistry.dartmouth.edu/sites/department_chemistry/files/styles/profile_portrait/public/default_images/facdir_default.jpg?itok=SwM_V3IC',
#    'rank': 'professor',
#    'first_name': 'Robert',
#    'middle_name': 'S.',
#    'last_name': 'Cantor'},
#   {'name': 'David S. Glueck',
#    'title': 'Professor of Chemistry',
# ...

# %% [markdown]
# # Yale

# %%
in_path = sys.path[0] + '/../data/yale/yale_w_profiles.json'
out_path = sys.path[0] + '/../data/yale/yale_w_profiles_processed.json'
yale_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
yale_processed[5]
# Out:
# {'department': 'Applied Physics',
#  'url': 'https://appliedphysics.yale.edu/',
#  'faculty_page': 'https://appliedphysics.yale.edu/faculty',
#  'success': True,
#  'profiles': [{'name': 'Charles Ahn',
#    'title': 'John C. Malone Professor of Applied Physics',
#    'img': 'https://appliedphysics.yale.edu/sites/default/files/styles/faculty_heads/public/ahn.jpg?itok=keotMCqZ',
#    'rank': 'professor',
#    'first_name': 'Charles',
#    'middle_name': None,
#    'last_name': 'Ahn'},
#   {'name': 'Hui Cao',
#    'title': 'John C. Malone Professor of Applied Physics, Professor of Physics, Professor of Electrical Engineering',
#    'img': 'https://appliedphysics.yale.edu/sites/default/files/styles/faculty_heads/public/hui_cao_may2018_190x183.jpg?itok=GaavsdCU',
#    'rank': 'professor',
#    'first_name': 'Hui',
#    'middle_name': None,
#    'last_name': 'Cao'},
#   {'name': 'Michel Devoret',
#    'title': 'Frederick W. Beinecke Professor of Applied Physics',
# ...

# %% [markdown]
# # Princeton

# %%
in_path = sys.path[0] + '/../data/princeton/princeton_w_profiles.json'
out_path = sys.path[0] + '/../data/princeton/princeton_w_profiles_processed.json'
princeton_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
princeton_processed[3]
# Out:
# {'department': 'Art and Archaeology',
#  'url': 'https://artandarchaeology.princeton.edu/',
#  'faculty_page': 'https://artandarchaeology.princeton.edu/people/faculty',
#  'success': True,
#  'profiles': [{'name': 'Bridget Alsdorf',
#    'title': 'Associate Professor of Art and Archaeology',
#    'img': 'https://artandarchaeology.princeton.edu/sites/artandarchaeology/files/styles/pwds_people_grid/public/people/21alsdorf_0.jpg?itok=UMDVeFks',
#    'rank': 'associate professor',
#    'first_name': 'Bridget',
#    'middle_name': None,
#    'last_name': 'Alsdorf'},
#   {'name': 'Anna Arabindan-Kesson',
#    'title': 'Assistant Professor of Art and Archaeology and African American Studies',
#    'img': 'https://artandarchaeology.princeton.edu/sites/artandarchaeology/files/styles/pwds_people_grid/public/people/22kessonp.jpg?itok=0RKqnn5C',
#    'rank': 'assistant professor',
#    'first_name': 'Anna',
#    'middle_name': None,
#    'last_name': 'Arabindan-Kesson'},
# ...

# %% [markdown]
# # Brown

# %%
in_path = sys.path[0] + '/../data/brown/brown_w_profiles.json'
out_path = sys.path[0] + '/../data/brown/brown_w_profiles_processed.json'
brown_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
brown_processed[3]
# Out:
# {'department': 'Division of Applied Mathematics',
#  'url': 'https://www.brown.edu/a-z/division-applied-mathematics',
#  'faculty_page': 'https://appliedmath.brown.edu/people/faculty',
#  'success': True,
#  'profiles': [{'name': 'Mark Ainsworth',
#    'title': 'Francis Wayland Professor of Applied Mathematics',
#    'img': 'https://www.brown.edu/sites/default/files/styles/square_xsml/public/Mark-Ainsworth.jpg?h=12f088be&itok=UOkZLqM1',
#    'rank': 'professor',
#    'first_name': 'Mark',
#    'middle_name': None,
#    'last_name': 'Ainsworth'},
#   {'name': 'Elie Bienenstock',
#    'title': 'Associate Professor Applied Mathematics',
#    'img': 'https://www.brown.edu/sites/default/files/styles/square_xsml/public/2020-09/Bienenstock%2016.jpg?h=a60e49bf&itok=ZsTVHP6v',
#    'rank': 'associate professor',
#    'first_name': 'Elie',
#    'middle_name': None,
#    'last_name': 'Bienenstock'},
#   {'name': 'Constantine Dafermos',
# ...

# %% [markdown]
# # Cornell

# %%
in_path = sys.path[0] + '/../data/cornell/cornell_w_profiles.json'
out_path = sys.path[0] + '/../data/cornell/cornell_w_profiles_processed.json'
cornell_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
cornell_processed[3]
# Out:
# {'department': 'Computational Biology',
#  'url': 'https://compbio.cornell.edu/',
#  'faculty_page': 'https://compbio.cornell.edu/people/faculty',
#  'success': True,
#  'profiles': [{'name': 'Sumanta Basu',
#    'title': 'Assistant Professor',
#    'img': 'https://compbio.cornell.edu/sites/compbio.cornell.edu/files/styles/people_medium/public/people/Sumanta%2C%20Basu_2.jpg?itok=nFcbf2Wc',
#    'rank': 'assistant professor',
#    'first_name': 'Sumanta',
#    'middle_name': None,
#    'last_name': 'Basu'},
#   {'name': 'James Booth',
#    'title': 'Professor',
#    'img': 'https://compbio.cornell.edu/sites/compbio.cornell.edu/files/styles/people_medium/public/people/Jim%20Booth_crop.jpg?itok=xvTeaUcx',
#    'rank': 'professor',
#    'first_name': 'James',
#    'middle_name': None,
#    'last_name': 'Booth'},
#   {'name': 'Andrew Clark',
#    'title': 'Professor and Chair',
# ...

# %% [markdown]
# # UPenn

# %%
in_path = sys.path[0] + '/../data/upenn/upenn_w_profiles.json'
out_path = sys.path[0] + '/../data/upenn/upenn_w_profiles_processed.json'
upenn_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
upenn_processed[3]
# Out:
# {'department': 'Chemistry',
#  'url': 'https://www.chem.upenn.edu/',
#  'faculty_page': 'https://www.chem.upenn.edu/people',
#  'success': True,
#  'profiles': [{'name': 'Jessica M. Anna',
#    'title': 'Assistant Professor of Chemistry',
#    'img': 'https://www.chem.upenn.edu/sites/default/files/styles/max_1300x1300/public/Annasmall.jpg?itok=vUB2OhbG',
#    'rank': 'assistant professor',
#    'first_name': 'Jessica',
#    'middle_name': 'M.',
#    'last_name': 'Anna'},
#   {'name': 'Tobias Baumgart',
#    'title': 'Professor of Chemistry',
#    'img': 'https://www.chem.upenn.edu/sites/default/files/styles/max_1300x1300/public/baumgart.jpg?itok=wczS1X7I',
#    'rank': 'professor',
#    'first_name': 'Tobias',
#    'middle_name': None,
#    'last_name': 'Baumgart'},
#   {'name': 'Donald H. Berry',
#    'title': 'Professor of Chemistry',
#    'img': 'https://www.chem.upenn.edu/sites/default/files/styles/max_1300x1300/public/berry.jpg?itok=IEcywU1Z',
#    'rank': 'professor',
# ...

# %% [markdown]
# # Harvard
