# %%
import sys
import json
from profile_cleaning import ProfileCleaning

# %%
p_cleaning = ProfileCleaning()

# %% [markdown]
# # Columbia

# %%
in_path = sys.path[0] + '/../data/columbia/columbia_test_sans_processing.json'
out_path = sys.path[0] + '/../data/columbia/columbia_test_processed.json'
columbia_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
columbia_processed[5]
# Out:
# {'department': 'Applied Physics and Applied Mathematics Department',
#  'url': 'http://apam.columbia.edu/',
#  'faculty_page': 'https://www.apam.columbia.edu/directory?gsarqfields%5Bbiotypetid%5D=30',
#  'success': True,
#  'profiles': [{'name': 'William Bailey',
#    'title': 'ASSOCIATE PROFESSOR OF MATERIALS SCIENCE AND ENGINEERING IN THE DEPARTMENT OF APPLIED PHYSICS AND APPLIED MATHEMATICS',
#    'img': 'https://www.apam.columbia.edu/files/seas/styles/300x300/public/content/bio_profile_image/2019/29/bailey_300.jpg?itok=Ay-w6css',
#    'rank': 'associate professor',
#    'first_name': 'William',
#    'middle_name': None,
#    'last_name': 'Bailey'},
#   {'name': 'Katayun Barmak',
#    'title': 'PHILIPS ELECTRONICS PROFESSOR OF APPLIED PHYSICS AND APPLIED MATHEMATICS',
#    'img': 'https://www.apam.columbia.edu/files/seas/styles/300x300/public/content/bio_profile_image/2017/14/barmak-preferred-1.jpg?itok=SIUjRpFt',
#    'rank': 'professor',
#    'first_name': 'Katayun',
# ...

# %% [markdown]
# # Dartmouth

# %%
in_path = sys.path[0] + '/../data/dartmouth/dartmouth_test_sans_processing.json'
out_path = sys.path[0] + '/../data/dartmouth/dartmouth_test_processed.json'
dartmouth_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
dartmouth_processed[5]
# Out:
# {'department': 'Chemistry',
#  'url': 'https://chemistry.dartmouth.edu/',
#  'faculty_page': 'https://chemistry.dartmouth.edu/people?field_people_local_tags_tid=1626',
#  'success': True,
#  'profiles': [{'name': 'Ivan Aprahamian',
#    'title': 'Professor of Chemistry',
#    'img': 'https://chemistry.dartmouth.edu/sites/department_chemistry/files/styles/profile_portrait/public/20140915-aprahamian-095_597_0_1.jpg?itok=bJ-Hcda5',
#    'rank': 'professor',
#    'first_name': 'Ivan',
#    'middle_name': None,
#    'last_name': 'Aprahamian'},
#   {'name': 'Robert S. Cantor',
#    'title': 'Professor of Chemistry',
#    'img': 'https://chemistry.dartmouth.edu/sites/department_chemistry/files/styles/profile_portrait/public/default_images/facdir_default.jpg?itok=SwM_V3IC',
#    'rank': 'professor',
#    'first_name': 'Robert',
#    'middle_name': 'S.',
#    'last_name': 'Cantor'},
#   {'name': 'David S. Glueck',
#    'title': 'Professor of Chemistry',
# ...

# %% [markdown]
# # Yale

# %%
in_path = sys.path[0] + '/../data/yale/yale_w_profiles.json'
out_path = sys.path[0] + '/../data/yale/yale_w_profiles_processed.json'
yale_processed = p_cleaning.clean_profiles(in_path, out_path)

# %%
yale_processed[5]
# Out:
# {'department': 'Applied Physics',
#  'url': 'https://appliedphysics.yale.edu/',
#  'faculty_page': 'https://appliedphysics.yale.edu/faculty',
#  'success': True,
#  'profiles': [{'name': 'Charles Ahn',
#    'title': 'John C. Malone Professor of Applied Physics',
#    'img': 'https://appliedphysics.yale.edu/sites/default/files/styles/faculty_heads/public/ahn.jpg?itok=keotMCqZ',
#    'rank': 'professor',
#    'first_name': 'Charles',
#    'middle_name': None,
#    'last_name': 'Ahn'},
#   {'name': 'Hui Cao',
#    'title': 'John C. Malone Professor of Applied Physics, Professor of Physics, Professor of Electrical Engineering',
#    'img': 'https://appliedphysics.yale.edu/sites/default/files/styles/faculty_heads/public/hui_cao_may2018_190x183.jpg?itok=GaavsdCU',
#    'rank': 'professor',
#    'first_name': 'Hui',
#    'middle_name': None,
#    'last_name': 'Cao'},
#   {'name': 'Michel Devoret',
#    'title': 'Frederick W. Beinecke Professor of Applied Physics',
# ...
